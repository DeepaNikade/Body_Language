# %%
# import numpy as np
# import cv2

# %%
# capture=cv2.VideoCapture(0)

# fourcc=cv2.VideoWriter_fourcc(*'XVID')
# out=cv2.VideoWriter('Intern/videos/interview.mp4',fourcc,20.0,(640,480))

# while(capture.isOpened()):
#     ret,frame=capture.read()
#     if(ret==True):
#         out.write(frame)
#         cv2.imshow('output',frame)
#         if(cv2.waitKey(1) & 0xFF==ord('q')):
#             break
#     else:
#         break
# capture.release()
# cv2.destroyAllWindows()

# %%
# !pip install mediapipe opencv-python

# %%
# !pip install opencv-contrib-python

# %%
# !pip install pandas scikit-learn

# %%
import mediapipe as mp
import cv2

# %%
mp_drawing=mp.solutions.drawing_utils
mp_holistic=mp.solutions.holistic

# %%
cap = cv2.VideoCapture(0)
# fourcc=cv2.VideoWriter_fourcc(*'XVID')


# directory='Intern/videos'

# video_files = [f for f in os.listdir(directory) if f.endswith('.mp4')]

# current_time = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
# output_file = f'Intern/videos/interview_{current_time}.mp4'

# print(video_files)

# out=cv2.VideoWriter(output_file,fourcc,20.0,(640,480))


# for filename in video_files:
#   capt=cv2.VideoCapture(filename)

# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret,frame=cap.read()
    
    
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
results.face_landmarks.landmark[0].visibility
# Out:
# 0.0

# %%
results.face_landmarks
# Out:
# landmark {
#   x: 0.5352958
#   y: 0.7090805
#   z: -0.045006704
# }
# landmark {
#   x: 0.5279283
#   y: 0.64804393
#   z: -0.07623172
# }
# landmark {
#   x: 0.53163445
#   y: 0.66952556
#   z: -0.042399075
# }
# landmark {
#   x: 0.5112229
#   y: 0.5813815
#   z: -0.053013448
# }
# landmark {
#   x: 0.52583396
#   y: 0.62612617
#   z: -0.08008678
# }
# landmark {
#   x: 0.5239453
#   y: 0.5982559
#   z: -0.07307915
# }
# landmark {
#   x: 0.52053046
#   y: 0.5331847
#   z: -0.030887589
# }
# landmark {
#   x: 0.42307165
#   y: 0.5531168
#   z: 0.030968431
# }
# landmark {
#   x: 0.51701367
#   y: 0.48204395
#   z: -0.018332094
# }
# landmark {
#   x: 0.5146586
#   y: 0.45292014
#   z: -0.019477366
# }
# landmark {
#   x: 0.5063797
#   y: 0.35384852
#   z: 0.0020452046
# }
# landmark {
#   x: 0.53619695
#   y: 0.7186825
#   z: -0.043444935
# }
# landmark {
#   x: 0.53716403
#   y: 0.72622037
#   z: -0.038959317
# }
# landmark {
#   x: 0.5379362
#   y: 0.7292082
#   z: -0.032956265
# }
# landmark {
#   x: 0.53835213
#   y: 0.73248994
#   z: -0.032792635
# }
# landmark {
#   x: 0.53896785
#   y: 0.7395878
#   z: -0.035612606
# }
# landmark {
#   x: 0.5397884
#   y: 0.74917495
#   z: -0.03969641
# }
# landmark {
#   x: 0.5409274
#   y: 0.7600568
#   z: -0.039295945
# }
# landmark {
#   x: 0.5432708
#   y: 0.7807113
#   z: -0.028461838
# }
# landmark {
#   x: 0.5294606
#   y: 0.6595774
#   z: -0.06954844
# }
# landmark {
#   x: 0.51707304
#   y: 0.6610607
#   z: -0.050097607
# }
# landmark {
#   x: 0.36931527
#   y: 0.48470515
#   z: 0.10761053
# }
# landmark {
#   x: 0.46346274
#   y: 0.5628591
#   z: 0.013097008
# }
# landmark {
#   x: 0.44986174
#   y: 0.56690073
#   z: 0.014930443
# }
# landmark {
#   x: 0.43677592
#   y: 0.56784505
#   z: 0.0199195
# }
# landmark {
#   x: 0.41877085
#   y: 0.5610624
#   z: 0.033272862
# }
# landmark {
#   x: 0.47457218
#   y: 0.5553568
#   z: 0.0143745765
# }
# landmark {
#   x: 0.44140944
#   y: 0.516097
#   z: 0.010360368
# }
# landmark {
#   x: 0.45559457
#   y: 0.5147372
#   z: 0.009812191
# }
# landmark {
#   x: 0.42837954
#   y: 0.5213724
#   z: 0.015988324
# }
# landmark {
#   x: 0.4200511
#   y: 0.52984804
#   z: 0.02221132
# }
# landmark {
#   x: 0.40890738
#   y: 0.57495785
#   z: 0.040385928
# }
# landmark {
#   x: 0.49666455
#   y: 0.8243187
#   z: -0.011208671
# }
# landmark {
#   x: 0.418361
#   y: 0.5496828
#   z: 0.036297202
# }
# landmark {
#   x: 0.37182176
#   y: 0.57414526
#   z: 0.1074835
# }
# landmark {
#   x: 0.39317706
#   y: 0.56404585
#   z: 0.05676433
# }
# landmark {
#   x: 0.45970747
#   y: 0.64350927
#   z: -0.005746177
# }
# landmark {
#   x: 0.5175635
#   y: 0.7092283
#   z: -0.0421148
# }
# landmark {
#   x: 0.5222509
#   y: 0.7285271
#   z: -0.036057502
# }
# landmark {
#   x: 0.5008313
#   y: 0.7193534
#   z: -0.033212636
# }
# landmark {
#   x: 0.4910428
#   y: 0.73027015
#   z: -0.022719136
# }
# landmark {
#   x: 0.50981367
#   y: 0.7324953
#   z: -0.029741473
# }
# landmark {
#   x: 0.5005663
#   y: 0.73714316
#   z: -0.020149877
# }
# landmark {
#   x: 0.479622
#   y: 0.7634746
#   z: -0.0041024867
# }
# landmark {
#   x: 0.51615673
#   y: 0.64986897
#   z: -0.07447514
# }
# landmark {
#   x: 0.51244766
#   y: 0.6288384
#   z: -0.07781818
# }
# landmark {
#   x: 0.39545766
#   y: 0.50938684
#   z: 0.030394254
# }
# landmark {
#   x: 0.4832436
#   y: 0.58897376
#   z: -0.005542369
# }
# landmark {
#   x: 0.48425078
#   y: 0.6506157
#   z: -0.03783153
# }
# landmark {
#   x: 0.4828109
#   y: 0.63965195
#   z: -0.033031765
# }
# landmark {
#   x: 0.4186974
#   y: 0.64899445
#   z: 0.0157209
# }
# landmark {
#   x: 0.5114796
#   y: 0.60289335
#   z: -0.067975834
# }
# landmark {
#   x: 0.42438766
#   y: 0.4793835
#   z: 0.0042297454
# }
# landmark {
#   x: 0.40657878
#   y: 0.49107942
#   z: 0.016866995
# }
# landmark {
#   x: 0.37717772
#   y: 0.44364637
#   z: 0.08050158
# }
# landmark {
#   x: 0.486413
#   y: 0.4833175
#   z: -0.012335985
# }
# landmark {
#   x: 0.46878982
#   y: 0.51836365
#   z: 0.013153948
# }
# landmark {
#   x: 0.4667611
#   y: 0.7483182
#   z: 0.0015564502
# }
# landmark {
#   x: 0.4072619
#   y: 0.75887585
#   z: 0.13169172
# }
# landmark {
#   x: 0.49577114
#   y: 0.6606419
#   z: -0.033622753
# }
# landmark {
#   x: 0.5083258
#   y: 0.66474783
#   z: -0.03645879
# }
# landmark {
#   x: 0.48173285
#   y: 0.745123
#   z: -0.0003249869
# }
# landmark {
#   x: 0.48795614
#   y: 0.7427828
#   z: -0.004628577
# }
# landmark {
#   x: 0.39749843
#   y: 0.47831568
#   z: 0.025191765
# }
# landmark {
#   x: 0.48504502
#   y: 0.6595044
#   z: -0.030591732
# }
# landmark {
#   x: 0.45010835
#   y: 0.47513974
#   z: -0.0057567526
# }
# landmark {
#   x: 0.4457386
#   y: 0.45734423
#   z: -0.0075240415
# }
# landmark {
#   x: 0.42571765
#   y: 0.38082826
#   z: 0.023859147
# }
# landmark {
#   x: 0.3871694
#   y: 0.45990986
#   z: 0.049016837
# }
# landmark {
#   x: 0.43690437
#   y: 0.41708833
#   z: 0.007571321
# }
# landmark {
#   x: 0.38660085
#   y: 0.5016309
#   z: 0.04401529
# }
# landmark {
#   x: 0.37772766
#   y: 0.49389842
#   z: 0.07373471
# }
# landmark {
#   x: 0.51967037
#   y: 0.7204902
#   z: -0.040732626
# }
# landmark {
#   x: 0.5058725
#   y: 0.7275381
#   z: -0.032210324
# }
# landmark {
#   x: 0.4958819
#   y: 0.734035
#   z: -0.022691483
# }
# landmark {
#   x: 0.49988267
#   y: 0.66338336
#   z: -0.03117008
# }
# landmark {
#   x: 0.48499638
#   y: 0.744158
#   z: -0.0025803882
# }
# landmark {
#   x: 0.4908934
#   y: 0.74495256
#   z: -0.012833287
# }
# landmark {
#   x: 0.48938742
#   y: 0.74173206
#   z: -0.005240716
# }
# landmark {
#   x: 0.5019355
#   y: 0.65310603
#   z: -0.05281223
# }
# landmark {
#   x: 0.5033646
#   y: 0.7355604
#   z: -0.01813152
# }
# landmark {
#   x: 0.51302034
#   y: 0.7327982
#   z: -0.024614967
# }
# landmark {
#   x: 0.524734
#   y: 0.7310829
#   z: -0.03038822
# }
# landmark {
#   x: 0.52592623
#   y: 0.78365153
#   z: -0.026960071
# }
# landmark {
#   x: 0.52465385
#   y: 0.76191515
#   z: -0.037285257
# }
# landmark {
#   x: 0.52404714
#   y: 0.750103
#   z: -0.03751676
# }
# landmark {
#   x: 0.5239306
#   y: 0.74066544
#   z: -0.033037245
# }
# landmark {
#   x: 0.52460265
#   y: 0.7344883
#   z: -0.030182425
# }
# landmark {
#   x: 0.50245774
#   y: 0.73861635
#   z: -0.018419571
# }
# landmark {
#   x: 0.5006982
#   y: 0.7409265
#   z: -0.021375496
# }
# landmark {
#   x: 0.49838614
#   y: 0.7464483
#   z: -0.02437084
# }
# landmark {
#   x: 0.49653727
#   y: 0.7538197
#   z: -0.022427185
# }
# landmark {
#   x: 0.4771564
#   y: 0.711802
#   z: -0.016874423
# }
# landmark {
#   x: 0.38401997
#   y: 0.6652598
#   z: 0.16091031
# }
# landmark {
#   x: 0.53047836
#   y: 0.6639513
#   z: -0.051543504
# }
# landmark {
#   x: 0.49640852
#   y: 0.7406727
#   z: -0.010924987
# }
# landmark {
#   x: 0.49381235
#   y: 0.7417097
#   z: -0.012749417
# }
# landmark {
#   x: 0.51379967
#   y: 0.6724605
#   z: -0.03800487
# }
# landmark {
#   x: 0.49154583
#   y: 0.670487
#   z: -0.021623516
# }
# landmark {
#   x: 0.51120144
#   y: 0.66882205
#   z: -0.037369426
# }
# landmark {
#   x: 0.46954945
#   y: 0.6035723
#   z: -0.00065750815
# }
# landmark {
#   x: 0.4482436
#   y: 0.6202711
#   z: 0.004288088
# }
# landmark {
#   x: 0.48173285
#   y: 0.64896774
#   z: -0.02538295
# }
# landmark {
#   x: 0.39460695
#   y: 0.4084986
#   z: 0.05063393
# }
# landmark {
#   x: 0.40562811
#   y: 0.4335985
#   z: 0.027374597
# }
# landmark {
#   x: 0.4175839
#   y: 0.46274424
#   z: 0.008274674
# }
# landmark {
#   x: 0.4920175
#   y: 0.77218014
#   z: -0.013231277
# }
# landmark {
#   x: 0.47934037
#   y: 0.4553522
#   z: -0.016451297
# }
# landmark {
#   x: 0.47091648
#   y: 0.40918672
#   z: -0.0048273844
# }
# landmark {
#   x: 0.46180344
#   y: 0.3640902
#   z: 0.007320996
# }
# landmark {
#   x: 0.42549056
#   y: 0.5665477
#   z: 0.026964987
# }
# landmark {
#   x: 0.39582652
#   y: 0.59141195
#   z: 0.048455104
# }
# landmark {
#   x: 0.4815266
#   y: 0.5483394
#   z: 0.016170822
# }
# landmark {
#   x: 0.40506583
#   y: 0.5372134
#   z: 0.03623136
# }
# landmark {
#   x: 0.49189982
#   y: 0.57342505
#   z: -0.010543106
# }
# landmark {
#   x: 0.49166945
#   y: 0.64166325
#   z: -0.05168204
# }
# landmark {
#   x: 0.38371715
#   y: 0.60826826
#   z: 0.064414255
# }
# landmark {
#   x: 0.40561014
#   y: 0.6031355
#   z: 0.03400477
# }
# landmark {
#   x: 0.42326793
#   y: 0.60657233
#   z: 0.01903848
# }
# landmark {
#   x: 0.44909495
#   y: 0.59906983
#   z: 0.011319466
# }
# landmark {
#   x: 0.46774292
#   y: 0.5877403
#   z: 0.007387839
# }
# landmark {
#   x: 0.48169523
#   y: 0.5752114
#   z: 0.0034887719
# }
# landmark {
#   x: 0.5076458
#   y: 0.5413604
#   z: -0.024769675
# }
# landmark {
#   x: 0.389119
#   y: 0.6496025
#   z: 0.057753157
# }
# landmark {
#   x: 0.3933668
#   y: 0.53514
#   z: 0.044175185
# }
# landmark {
#   x: 0.52243996
#   y: 0.6599284
#   z: -0.068313055
# }
# landmark {
#   x: 0.48580277
#   y: 0.60813767
#   z: -0.013071852
# }
# landmark {
#   x: 0.37097532
#   y: 0.57544845
#   z: 0.15627764
# }
# landmark {
#   x: 0.49146003
#   y: 0.5615915
#   z: 0.0014392381
# }
# landmark {
#   x: 0.48118335
#   y: 0.6506566
#   z: -0.011502175
# }
# landmark {
#   x: 0.41391248
#   y: 0.5511018
#   z: 0.03941092
# }
# landmark {
#   x: 0.49039724
#   y: 0.6280862
#   z: -0.04566957
# }
# landmark {
#   x: 0.39331567
#   y: 0.71211755
#   z: 0.15037744
# }
# landmark {
#   x: 0.481136
#   y: 0.54101264
#   z: 0.020245425
# }
# landmark {
#   x: 0.50046355
#   y: 0.61320037
#   z: -0.059327364
# }
# landmark {
#   x: 0.43624932
#   y: 0.79482466
#   z: 0.0495235
# }
# landmark {
#   x: 0.44159007
#   y: 0.81782037
#   z: 0.074182875
# }
# landmark {
#   x: 0.3802716
#   y: 0.6595405
#   z: 0.10946076
# }
# landmark {
#   x: 0.41708976
#   y: 0.77341145
#   z: 0.07083575
# }
# landmark {
#   x: 0.37421137
#   y: 0.53147954
#   z: 0.09502977
# }
# landmark {
#   x: 0.4961448
#   y: 0.844429
#   z: -0.003845759
# }
# landmark {
#   x: 0.5248619
#   y: 0.6642226
#   z: -0.05047149
# }
# landmark {
#   x: 0.47483224
#   y: 0.62529385
#   z: -0.00825289
# }
# landmark {
#   x: 0.3826328
#   y: 0.5701741
#   z: 0.071732156
# }
# landmark {
#   x: 0.4366027
#   y: 0.5562219
#   z: 0.02118917
# }
# landmark {
#   x: 0.44866002
#   y: 0.5559473
#   z: 0.017020537
# }
# landmark {
#   x: 0.48804533
#   y: 0.7498911
#   z: -0.010371169
# }
# landmark {
#   x: 0.39574772
#   y: 0.6895672
#   z: 0.05895715
# }
# landmark {
#   x: 0.5232813
#   y: 0.86598593
#   z: -0.0030627912
# }
# landmark {
#   x: 0.48238695
#   y: 0.85022676
#   z: 0.03042419
# }
# landmark {
#   x: 0.46387115
#   y: 0.8376728
#   z: 0.049619958
# }
# landmark {
#   x: 0.5104783
#   y: 0.40318513
#   z: -0.009789929
# }
# landmark {
#   x: 0.5512616
#   y: 0.8648824
#   z: -0.009085397
# }
# landmark {
#   x: 0.46019614
#   y: 0.5527305
#   z: 0.015851347
# }
# landmark {
#   x: 0.47075063
#   y: 0.5474736
#   z: 0.01738868
# }
# landmark {
#   x: 0.47755226
#   y: 0.5438881
#   z: 0.020325167
# }
# landmark {
#   x: 0.383775
#   y: 0.5328324
#   z: 0.059673455
# }
# landmark {
#   x: 0.46873796
#   y: 0.5326196
#   z: 0.015637096
# }
# landmark {
#   x: 0.45669204
#   y: 0.5315255
#   z: 0.013853944
# }
# landmark {
#   x: 0.44524112
#   y: 0.53270936
#   z: 0.015267045
# }
# landmark {
#   x: 0.43375432
#   y: 0.5372995
#   z: 0.01948586
# }
# landmark {
#   x: 0.42636234
#   y: 0.5426166
#   z: 0.024413757
# }
# landmark {
#   x: 0.36742926
#   y: 0.5259537
#   z: 0.13570619
# }
# landmark {
#   x: 0.42854863
#   y: 0.5548364
#   z: 0.026472956
# }
# landmark {
#   x: 0.5329592
#   y: 0.68188405
#   z: -0.040005837
# }
# landmark {
#   x: 0.48807213
#   y: 0.69824326
#   z: -0.024304567
# }
# landmark {
#   x: 0.4949367
#   y: 0.65774107
#   z: -0.038624015
# }
# landmark {
#   x: 0.51371527
#   y: 0.6868244
#   z: -0.03819872
# }
# landmark {
#   x: 0.5190369
#   y: 0.5079891
#   z: -0.019209972
# }
# landmark {
#   x: 0.45704812
#   y: 0.81561923
#   z: 0.0319152
# }
# landmark {
#   x: 0.47608718
#   y: 0.83030903
#   z: 0.014591379
# }
# landmark {
#   x: 0.52051455
#   y: 0.85274744
#   z: -0.020164924
# }
# landmark {
#   x: 0.42364842
#   y: 0.7940994
#   z: 0.10444027
# }
# landmark {
#   x: 0.47722933
#   y: 0.53708607
#   z: 0.018552216
# }
# landmark {
#   x: 0.50084406
#   y: 0.5755445
#   z: -0.030841406
# }
# landmark {
#   x: 0.5494659
#   y: 0.8503939
#   z: -0.025454195
# }
# landmark {
#   x: 0.50149107
#   y: 0.86014116
#   z: 0.010763885
# }
# landmark {
#   x: 0.38913608
#   y: 0.7026517
#   z: 0.103725486
# }
# landmark {
#   x: 0.5123251
#   y: 0.7361893
#   z: -0.024685245
# }
# landmark {
#   x: 0.5107894
#   y: 0.7407592
#   z: -0.027838074
# }
# landmark {
#   x: 0.5096229
#   y: 0.7485471
#   z: -0.031511504
# }
# landmark {
#   x: 0.5092409
#   y: 0.75912046
#   z: -0.030660303
# }
# landmark {
#   x: 0.5073168
#   y: 0.7794584
#   z: -0.02177623
# }
# landmark {
#   x: 0.4927743
#   y: 0.7409278
#   z: -0.011559301
# }
# landmark {
#   x: 0.4883512
#   y: 0.7403947
#   z: -0.011345317
# }
# landmark {
#   x: 0.48405915
#   y: 0.73845285
#   z: -0.011092457
# }
# landmark {
#   x: 0.46897808
#   y: 0.7291317
#   z: -0.007218863
# }
# landmark {
#   x: 0.4128705
#   y: 0.69495815
#   z: 0.028093463
# }
# landmark {
#   x: 0.4999089
#   y: 0.55602384
#   z: -0.01661677
# }
# landmark {
#   x: 0.49002263
#   y: 0.52168083
#   z: 0.010015796
# }
# landmark {
#   x: 0.4823017
#   y: 0.52884245
#   z: 0.015987884
# }
# landmark {
#   x: 0.49560994
#   y: 0.73797005
#   z: -0.01054554
# }
# landmark {
#   x: 0.4179757
#   y: 0.74333096
#   z: 0.045705773
# }
# landmark {
#   x: 0.5014142
#   y: 0.51576686
#   z: -0.009011888
# }
# landmark {
#   x: 0.50156
#   y: 0.80240667
#   z: -0.016008165
# }
# landmark {
#   x: 0.52288616
#   y: 0.57586455
#   z: -0.058499966
# }
# landmark {
#   x: 0.50922114
#   y: 0.5623381
#   z: -0.04029661
# }
# landmark {
#   x: 0.52180475
#   y: 0.55532724
#   z: -0.04414322
# }
# landmark {
#   x: 0.49361607
#   y: 0.609815
#   z: -0.032164577
# }
# landmark {
#   x: 0.547507
#   y: 0.8298951
#   z: -0.031896804
# }
# landmark {
#   x: 0.54532623
#   y: 0.80415285
#   z: -0.030303337
# }
# landmark {
#   x: 0.5231727
#   y: 0.8077653
#   z: -0.02640683
# }
# landmark {
#   x: 0.467611
#   y: 0.77515733
#   z: 0.0038765138
# }
# landmark {
#   x: 0.47178444
#   y: 0.6682294
#   z: -0.008372016
# }
# landmark {
#   x: 0.4838287
#   y: 0.7917236
#   z: -0.005885469
# }
# landmark {
#   x: 0.4399407
#   y: 0.67044264
#   z: -0.00061637565
# }
# landmark {
#   x: 0.4608664
#   y: 0.68970704
#   z: -0.006754411
# }
# landmark {
#   x: 0.43179557
#   y: 0.70520866
#   z: 0.009094375
# }
# landmark {
#   x: 0.52055305
#   y: 0.83304465
#   z: -0.026526507
# }
# landmark {
#   x: 0.4866601
#   y: 0.62344897
#   z: -0.022459222
# }
# landmark {
#   x: 0.45803487
#   y: 0.79245245
#   z: 0.01700348
# }
# landmark {
#   x: 0.47762293
#   y: 0.80959016
#   z: 0.004073951
# }
# landmark {
#   x: 0.4534591
#   y: 0.75388604
#   z: 0.00866845
# }
# landmark {
#   x: 0.40333378
#   y: 0.7229161
#   z: 0.06113294
# }
# landmark {
#   x: 0.43713307
#   y: 0.7601861
#   z: 0.023733938
# }
# landmark {
#   x: 0.40026093
#   y: 0.74100506
#   z: 0.09383464
# }
# landmark {
#   x: 0.45289
#   y: 0.7176376
#   z: -0.00093109685
# }
# landmark {
#   x: 0.49353063
#   y: 0.59157455
#   z: -0.02122836
# }
# landmark {
#   x: 0.4969684
#   y: 0.6503449
#   z: -0.05521306
# }
# landmark {
#   x: 0.4889219
#   y: 0.656837
#   z: -0.040125683
# }
# landmark {
#   x: 0.5012332
#   y: 0.6345159
#   z: -0.06495245
# }
# landmark {
#   x: 0.47711
#   y: 0.506461
#   z: 0.0070090815
# }
# landmark {
#   x: 0.45393857
#   y: 0.50021994
#   z: 0.0060462067
# }
# landmark {
#   x: 0.4347883
#   y: 0.501985
#   z: 0.008011086
# }
# landmark {
#   x: 0.41927403
#   y: 0.50844514
#   z: 0.01500199
# }
# landmark {
#   x: 0.40911126
#   y: 0.5198922
#   z: 0.024610702
# }
# landmark {
#   x: 0.40483326
#   y: 0.5569649
#   z: 0.045716513
# }
# landmark {
#   x: 0.37409014
#   y: 0.616924
#   z: 0.10948544
# }
# landmark {
#   x: 0.41673774
#   y: 0.5820042
#   z: 0.032062937
# }
# landmark {
#   x: 0.4308202
#   y: 0.5845373
#   z: 0.022354234
# }
# landmark {
#   x: 0.44885874
#   y: 0.58172774
#   z: 0.015329361
# }
# landmark {
#   x: 0.4659001
#   y: 0.5742778
#   z: 0.011597944
# }
# landmark {
#   x: 0.47900185
#   y: 0.5647242
#   z: 0.010983249
# }
# landmark {
#   x: 0.48773423
#   y: 0.5555681
#   z: 0.009720168
# }
# landmark {
#   x: 0.37752247
#   y: 0.6204654
#   z: 0.16358522
# }
# landmark {
#   x: 0.49025434
#   y: 0.661822
#   z: -0.033463985
# }
# landmark {
#   x: 0.5015877
#   y: 0.59354234
#   z: -0.04303287
# }
# landmark {
#   x: 0.50648636
#   y: 0.6492466
#   z: -0.06687494
# }
# landmark {
#   x: 0.51573324
#   y: 0.6580763
#   z: -0.062398788
# }
# landmark {
#   x: 0.5072814
#   y: 0.65292907
#   z: -0.06023542
# }
# landmark {
#   x: 0.49515337
#   y: 0.6669153
#   z: -0.02934623
# }
# landmark {
#   x: 0.5181274
#   y: 0.6594113
#   z: -0.06632066
# }
# landmark {
#   x: 0.5203247
#   y: 0.66361564
#   z: -0.05026511
# }
# landmark {
#   x: 0.48593345
#   y: 0.5406865
#   z: 0.017695766
# }
# landmark {
#   x: 0.49398613
#   y: 0.5423549
#   z: 0.008204179
# }
# landmark {
#   x: 0.49820158
#   y: 0.54352117
#   z: -0.002203171
# }
# landmark {
#   x: 0.42188528
#   y: 0.5464833
#   z: 0.029517584
# }
# landmark {
#   x: 0.41360083
#   y: 0.5388695
#   z: 0.03097684
# }
# landmark {
#   x: 0.5356166
#   y: 0.5774327
#   z: -0.05449291
# }
# landmark {
#   x: 0.62756765
#   y: 0.51845056
#   z: 0.02085154
# }
# landmark {
#   x: 0.5435642
#   y: 0.65668696
#   z: -0.051196203
# }
# landmark {
#   x: 0.6759914
#   y: 0.4319445
#   z: 0.09209695
# }
# landmark {
#   x: 0.5873151
#   y: 0.54198104
#   z: 0.006500148
# }
# landmark {
#   x: 0.60202795
#   y: 0.5413532
#   z: 0.007183082
# }
# landmark {
#   x: 0.6158217
#   y: 0.53784883
#   z: 0.010677549
# }
# landmark {
#   x: 0.6336064
#   y: 0.52477235
#   z: 0.022543062
# }
# landmark {
#   x: 0.57455164
#   y: 0.53829134
#   z: 0.009247339
# }
# landmark {
#   x: 0.6015252
#   y: 0.48738298
#   z: 0.0020698542
# }
# landmark {
#   x: 0.58670425
#   y: 0.49102905
#   z: 0.0033260004
# }
# landmark {
#   x: 0.61612576
#   y: 0.48814124
#   z: 0.0063555306
# }
# landmark {
#   x: 0.62648994
#   y: 0.49374238
#   z: 0.011900002
# }
# landmark {
#   x: 0.6462877
#   y: 0.53496563
#   z: 0.028875194
# }
# landmark {
#   x: 0.59894353
#   y: 0.80908847
#   z: -0.015991803
# }
# landmark {
#   x: 0.632002
#   y: 0.51315176
#   z: 0.025702016
# }
# landmark {
#   x: 0.6889035
#   y: 0.5207133
#   z: 0.0917396
# }
# landmark {
#   x: 0.66169965
#   y: 0.5184324
#   z: 0.043752424
# }
# landmark {
#   x: 0.6027586
#   y: 0.61993366
#   z: -0.012237238
# }
# landmark {
#   x: 0.55316967
#   y: 0.703415
#   z: -0.0439745
# }
# landmark {
#   x: 0.55303806
#   y: 0.723492
#   z: -0.03782141
# }
# landmark {
#   x: 0.5731089
#   y: 0.70791125
#   z: -0.03693133
# }
# landmark {
#   x: 0.5860973
#   y: 0.7148502
#   z: -0.027895585
# }
# landmark {
#   x: 0.56718326
#   y: 0.72333753
#   z: -0.033234406
# }
# landmark {
#   x: 0.5782291
#   y: 0.72451186
#   z: -0.024586836
# }
# landmark {
#   x: 0.6056752
#   y: 0.743059
#   z: -0.010506931
# }
# landmark {
#   x: 0.5400634
#   y: 0.64573103
#   z: -0.07544563
# }
# landmark {
#   x: 0.5398987
#   y: 0.6242736
#   z: -0.07893187
# }
# landmark {
#   x: 0.6489059
#   y: 0.4643379
#   z: 0.018200688
# }
# landmark {
#   x: 0.5696699
#   y: 0.574564
#   z: -0.009890024
# }
# landmark {
#   x: 0.5755313
#   y: 0.6355439
#   z: -0.04203133
# }
# landmark {
#   x: 0.5757184
#   y: 0.62431467
#   z: -0.037357293
# }
# landmark {
#   x: 0.6470687
#   y: 0.61125773
#   z: 0.0049828384
# }
# landmark {
#   x: 0.5374554
#   y: 0.5986251
#   z: -0.069336444
# }
# landmark {
#   x: 0.61208135
#   y: 0.4449641
#   z: -0.0039716614
# }
# landmark {
#   x: 0.633181
#   y: 0.45019138
#   z: 0.006319852
# }
# landmark {
#   x: 0.65864885
#   y: 0.39460745
#   z: 0.06637858
# }
# landmark {
#   x: 0.54844636
#   y: 0.47188818
#   z: -0.014804591
# }
# landmark {
#   x: 0.57402337
#   y: 0.49953318
#   z: 0.0079388395
# }
# landmark {
#   x: 0.6158087
#   y: 0.7240855
#   z: -0.0059060683
# }
# landmark {
#   x: 0.68667793
#   y: 0.7140382
#   z: 0.11729975
# }
# landmark {
#   x: 0.5660437
#   y: 0.64898217
#   z: -0.037001193
# }
# landmark {
#   x: 0.55422676
#   y: 0.6571382
#   z: -0.038075875
# }
# landmark {
#   x: 0.59993947
#   y: 0.7255272
#   z: -0.006890663
# }
# landmark {
#   x: 0.59367305
#   y: 0.7251473
#   z: -0.010484494
# }
# landmark {
#   x: 0.6408751
#   y: 0.43436432
#   z: 0.014055897
# }
# landmark {
#   x: 0.57719886
#   y: 0.6442411
#   z: -0.034723606
# }
# landmark {
#   x: 0.5843392
#   y: 0.45031828
#   z: -0.011407716
# }
# landmark {
#   x: 0.5855489
#   y: 0.4314685
#   z: -0.013289263
# }
# landmark {
#   x: 0.5935778
#   y: 0.35087323
#   z: 0.015947111
# }
# landmark {
#   x: 0.6495854
#   y: 0.41368037
#   z: 0.0365754
# }
# landmark {
#   x: 0.5878403
#   y: 0.38988808
#   z: 0.0007381195
# }
# landmark {
#   x: 0.6574188
#   y: 0.45376545
#   z: 0.030814864
# }
# landmark {
#   x: 0.6668898
#   y: 0.44379514
#   z: 0.059558872
# }
# landmark {
#   x: 0.55352217
#   y: 0.7149941
#   z: -0.042603366
# }
# landmark {
#   x: 0.56979233
#   y: 0.7173267
#   z: -0.03591819
# }
# landmark {
#   x: 0.5820448
#   y: 0.72004235
#   z: -0.02757569
# }
# landmark {
#   x: 0.56270975
#   y: 0.65301186
#   z: -0.033676874
# }
# landmark {
#   x: 0.59654236
#   y: 0.72552526
#   z: -0.008770975
# }
# landmark {
#   x: 0.59036714
#   y: 0.72845536
#   z: -0.01813422
# }
# landmark {
#   x: 0.59230417
#   y: 0.72474396
#   z: -0.010805403
# }
# landmark {
#   x: 0.5569903
#   y: 0.643917
#   z: -0.055721913
# }
# landmark {
#   x: 0.57569474
#   y: 0.72374326
#   z: -0.022256033
# }
# landmark {
#   x: 0.5646189
#   y: 0.7245653
#   z: -0.027807377
# }
# landmark {
#   x: 0.55191606
#   y: 0.7266314
#   z: -0.032085177
# }
# landmark {
#   x: 0.56148636
#   y: 0.77814424
#   z: -0.028545456
# }
# landmark {
#   x: 0.5579048
#   y: 0.7565923
#   z: -0.03919082
# }
# landmark {
#   x: 0.55606586
#   y: 0.7450012
#   z: -0.039520025
# }
# landmark {
#   x: 0.55432034
#   y: 0.7358006
#   z: -0.03499472
# }
# landmark {
#   x: 0.55286306
#   y: 0.7300216
#   z: -0.032077543
# }
# landmark {
#   x: 0.5774241
#   y: 0.72636306
#   z: -0.02257849
# }
# landmark {
#   x: 0.579391
#   y: 0.7279925
#   z: -0.02560496
# }
# landmark {
#   x: 0.5824691
#   y: 0.73257744
#   z: -0.028604966
# }
# landmark {
#   x: 0.58568245
#   y: 0.7390293
#   z: -0.026766177
# }
# landmark {
#   x: 0.5968363
#   y: 0.69245833
#   z: -0.02265398
# }
# landmark {
#   x: 0.6957259
#   y: 0.61361086
#   z: 0.14471292
# }
# landmark {
#   x: 0.5844213
#   y: 0.7261802
#   z: -0.016020609
# }
# landmark {
#   x: 0.58693105
#   y: 0.7264035
#   z: -0.017920183
# }
# landmark {
#   x: 0.5501068
#   y: 0.66649926
#   z: -0.039546967
# }
# landmark {
#   x: 0.5734107
#   y: 0.6570769
#   z: -0.024941117
# }
# landmark {
#   x: 0.5520386
#   y: 0.66207623
#   z: -0.038976364
# }
# landmark {
#   x: 0.5862915
#   y: 0.5842121
#   z: -0.006327043
# }
# landmark {
#   x: 0.61115736
#   y: 0.5933892
#   z: -0.0033528553
# }
# landmark {
#   x: 0.5791447
#   y: 0.6329014
#   z: -0.029892724
# }
# landmark {
#   x: 0.6324312
#   y: 0.36647865
#   z: 0.039165862
# }
# landmark {
#   x: 0.6245296
#   y: 0.39436024
#   z: 0.017214019
# }
# landmark {
#   x: 0.6162273
#   y: 0.4262939
#   z: -0.0005586493
# }
# landmark {
#   x: 0.5943775
#   y: 0.7559732
#   z: -0.018500844
# }
# landmark {
#   x: 0.55071294
#   y: 0.44185388
#   z: -0.019269854
# }
# landmark {
#   x: 0.55124545
#   y: 0.3947755
#   z: -0.008288548
# }
# landmark {
#   x: 0.55293626
#   y: 0.34778437
#   z: 0.0032797193
# }
# landmark {
#   x: 0.6274915
#   y: 0.53261644
#   z: 0.016673503
# }
# landmark {
#   x: 0.66291916
#   y: 0.5466453
#   z: 0.03566349
# }
# landmark {
#   x: 0.5663442
#   y: 0.53381455
#   z: 0.011614691
# }
# landmark {
#   x: 0.64388204
#   y: 0.49581045
#   z: 0.024480948
# }
# landmark {
#   x: 0.55806375
#   y: 0.5623028
#   z: -0.014008437
# }
# landmark {
#   x: 0.5653289
#   y: 0.62946093
#   z: -0.055091996
# }
# landmark {
#   x: 0.6792464
#   y: 0.55884975
#   z: 0.04992498
# }
# landmark {
#   x: 0.6537585
#   y: 0.56165296
#   z: 0.021855319
# }
# landmark {
#   x: 0.63531214
#   y: 0.5712449
#   z: 0.008834619
# }
# landmark {
#   x: 0.607315
#   y: 0.5728161
#   z: 0.0036757533
# }
# landmark {
#   x: 0.5861766
#   y: 0.5679431
#   z: 0.0015320022
# }
# landmark {
#   x: 0.5698187
#   y: 0.560413
#   z: -0.0010874838
# }
# landmark {
#   x: 0.5352733
#   y: 0.536582
#   z: -0.026278092
# }
# landmark {
#   x: 0.6800741
#   y: 0.60138947
#   z: 0.043375246
# }
# landmark {
#   x: 0.6560554
#   y: 0.48974591
#   z: 0.031269975
# }
# landmark {
#   x: 0.5367146
#   y: 0.65747994
#   z: -0.06908704
# }
# landmark {
#   x: 0.5694751
#   y: 0.5943155
#   z: -0.017302234
# }
# landmark {
#   x: 0.693123
#   y: 0.52118313
#   z: 0.13965136
# }
# landmark {
#   x: 0.5573511
#   y: 0.55042577
#   z: -0.0020054998
# }
# landmark {
#   x: 0.58077884
#   y: 0.6341748
#   z: -0.01569763
# }
# landmark {
#   x: 0.63712716
#   y: 0.5129178
#   z: 0.028323354
# }
# landmark {
#   x: 0.56504667
#   y: 0.6157517
#   z: -0.049143724
# }
# landmark {
#   x: 0.69378155
#   y: 0.6629541
#   z: 0.13505761
# }
# landmark {
#   x: 0.5659159
#   y: 0.52650815
#   z: 0.015585439
# }
# landmark {
#   x: 0.5512577
#   y: 0.6048324
#   z: -0.061833415
# }
# landmark {
#   x: 0.65827453
#   y: 0.760434
#   z: 0.03882877
# }
# landmark {
#   x: 0.6589684
#   y: 0.7846257
#   z: 0.06326525
# }
# landmark {
#   x: 0.694333
#   y: 0.6074497
#   z: 0.09378562
# }
# landmark {
#   x: 0.6750269
#   y: 0.7326522
#   z: 0.05834439
# }
# landmark {
#   x: 0.6781005
#   y: 0.47955185
#   z: 0.07988821
# }
# landmark {
#   x: 0.603341
#   y: 0.82869947
#   z: -0.0089784395
# }
# landmark {
#   x: 0.5361115
#   y: 0.6622347
#   z: -0.05093442
# }
# landmark {
#   x: 0.5839188
#   y: 0.6072817
#   z: -0.013420717
# }
# landmark {
#   x: 0.6745568
#   y: 0.5208223
#   z: 0.057500318
# }
# landmark {
#   x: 0.6138762
#   y: 0.5264958
#   z: 0.012288893
# }
# landmark {
#   x: 0.60137635
#   y: 0.530272
#   z: 0.0091584185
# }
# landmark {
#   x: 0.5941066
#   y: 0.7322774
#   z: -0.016112274
# }
# landmark {
#   x: 0.6802794
#   y: 0.6429508
#   z: 0.04515335
# }
# landmark {
#   x: 0.57956094
#   y: 0.85798943
#   z: -0.005969612
# }
# landmark {
#   x: 0.62058073
#   y: 0.82994145
#   z: 0.023191154
# }
# landmark {
#   x: 0.6383844
#   y: 0.8115986
#   z: 0.040709425
# }
# landmark {
#   x: 0.58897215
#   y: 0.5308822
#   z: 0.009127538
# }
# landmark {
#   x: 0.57731146
#   y: 0.5291812
#   z: 0.011692981
# }
# landmark {
#   x: 0.56992966
#   y: 0.52805555
#   z: 0.015167158
# }
# landmark {
#   x: 0.66647995
#   y: 0.48395693
#   z: 0.04566003
# }
# landmark {
#   x: 0.577089
#   y: 0.5138893
#   z: 0.009657692
# }
# landmark {
#   x: 0.58910865
#   y: 0.5084292
#   z: 0.006915308
# }
# landmark {
#   x: 0.60094076
#   y: 0.5057819
#   z: 0.007257261
# }
# landmark {
#   x: 0.61344403
#   y: 0.5063065
#   z: 0.010210257
# }
# landmark {
#   x: 0.6220074
#   y: 0.50896037
#   z: 0.014626852
# }
# landmark {
#   x: 0.68671125
#   y: 0.47165862
#   z: 0.11939192
# }
# landmark {
#   x: 0.6220149
#   y: 0.5222692
#   z: 0.016838277
# }
# landmark {
#   x: 0.5824572
#   y: 0.68294233
#   z: -0.028695406
# }
# landmark {
#   x: 0.5658459
#   y: 0.64594805
#   z: -0.041507624
# }
# landmark {
#   x: 0.55323315
#   y: 0.68043536
#   z: -0.04011664
# }
# landmark {
#   x: 0.64006805
#   y: 0.78774536
#   z: 0.023207098
# }
# landmark {
#   x: 0.622414
#   y: 0.80856246
#   z: 0.007710256
# }
# landmark {
#   x: 0.57919824
#   y: 0.8441893
#   z: -0.022989254
# }
# landmark {
#   x: 0.67460173
#   y: 0.75485826
#   z: 0.09130822
# }
# landmark {
#   x: 0.56913555
#   y: 0.5212466
#   z: 0.013233885
# }
# landmark {
#   x: 0.54739517
#   y: 0.56781346
#   z: -0.033169527
# }
# landmark {
#   x: 0.6015891
#   y: 0.8456833
#   z: 0.0054105483
# }
# landmark {
#   x: 0.69246763
#   y: 0.65300894
#   z: 0.08865622
# }
# landmark {
#   x: 0.5661772
#   y: 0.7274965
#   z: -0.028085254
# }
# landmark {
#   x: 0.56841254
#   y: 0.73143077
#   z: -0.031228479
# }
# landmark {
#   x: 0.57081544
#   y: 0.738535
#   z: -0.03503061
# }
# landmark {
#   x: 0.5732538
#   y: 0.74870557
#   z: -0.034214526
# }
# landmark {
#   x: 0.57980007
#   y: 0.7682191
#   z: -0.025743881
# }
# landmark {
#   x: 0.58783257
#   y: 0.7252797
#   z: -0.017094877
# }
# landmark {
#   x: 0.5917577
#   y: 0.72345173
#   z: -0.017173672
# }
# landmark {
#   x: 0.59569645
#   y: 0.720092
#   z: -0.017281765
# }
# landmark {
#   x: 0.60919976
#   y: 0.7064199
#   z: -0.014253131
# }
# landmark {
#   x: 0.6620464
#   y: 0.65423906
#   z: 0.016449807
# }
# landmark {
#   x: 0.5463216
#   y: 0.5481053
#   z: -0.019089565
# }
# landmark {
#   x: 0.5526298
#   y: 0.5108068
#   z: 0.0066846637
# }
# landmark {
#   x: 0.56222624
#   y: 0.51493454
#   z: 0.011623529
# }
# landmark {
#   x: 0.58478564
#   y: 0.72334427
#   z: -0.015747434
# }
# landmark {
#   x: 0.6668757
#   y: 0.70349765
#   z: 0.033873014
# }
# landmark {
#   x: 0.5386976
#   y: 0.5091514
#   z: -0.010871225
# }
# landmark {
#   x: 0.59008014
#   y: 0.7889624
#   z: -0.020145036
# }
# landmark {
#   x: 0.535694
#   y: 0.55797696
#   z: -0.041587368
# }
# landmark {
#   x: 0.56004167
#   y: 0.5988467
#   z: -0.03536857
# }
# landmark {
#   x: 0.5684759
#   y: 0.8009636
#   z: -0.028492808
# }
# landmark {
#   x: 0.6203972
#   y: 0.7511692
#   z: -0.0031950606
# }
# landmark {
#   x: 0.5941924
#   y: 0.64814365
#   z: -0.013953918
# }
# landmark {
#   x: 0.6067
#   y: 0.7727635
#   z: -0.011575635
# }
# landmark {
#   x: 0.6281531
#   y: 0.63965136
#   z: -0.008948214
# }
# landmark {
#   x: 0.60977817
#   y: 0.6656043
#   z: -0.0134979775
# }
# landmark {
#   x: 0.64353323
#   y: 0.6708745
#   z: -0.0004435034
# }
# landmark {
#   x: 0.5755342
#   y: 0.82497835
#   z: -0.029117951
# }
# landmark {
#   x: 0.57015204
#   y: 0.60967416
#   z: -0.026357744
# }
# landmark {
#   x: 0.6338755
#   y: 0.7652197
#   z: 0.008689388
# }
# landmark {
#   x: 0.6165534
#   y: 0.78849363
#   z: -0.0021856667
# }
# landmark {
#   x: 0.63082993
#   y: 0.72554153
#   z: 0.00011160127
# }
# landmark {
#   x: 0.67883956
#   y: 0.6783119
#   z: 0.04786069
# }
# landmark {
#   x: 0.64939696
#   y: 0.7265941
#   z: 0.013673569
# }
# landmark {
#   x: 0.6875334
#   y: 0.6946875
#   z: 0.07951369
# }
# landmark {
#   x: 0.62381303
#   y: 0.69003797
#   z: -0.009025407
# }
# landmark {
#   x: 0.55814016
#   y: 0.58091295
#   z: -0.024581473
# }
# landmark {
#   x: 0.5612478
#   y: 0.6397054
#   z: -0.05830895
# }
# landmark {
#   x: 0.57172203
#   y: 0.64317656
#   z: -0.043802895
# }
# landmark {
#   x: 0.5531652
#   y: 0.626007
#   z: -0.067624055
# }
# landmark {
#   x: 0.5631282
#   y: 0.49107516
#   z: 0.0027130698
# }
# landmark {
#   x: 0.58559406
#   y: 0.47633785
#   z: 4.052072e-05
# }
# landmark {
#   x: 0.60556877
#   y: 0.47124043
#   z: 0.00017716487
# }
# landmark {
#   x: 0.6229364
#   y: 0.47229648
#   z: 0.0051693544
# }
# landmark {
#   x: 0.63612926
#   y: 0.47995532
#   z: 0.01369582
# }
# landmark {
#   x: 0.647945
#   y: 0.51548827
#   z: 0.03379542
# }
# landmark {
#   x: 0.69373935
#   y: 0.563536
#   z: 0.093345374
# }
# landmark {
#   x: 0.638898
#   y: 0.54460686
#   z: 0.021150872
# }
# landmark {
#   x: 0.6243467
#   y: 0.552244
#   z: 0.012864071
# }
# landmark {
#   x: 0.6051694
#   y: 0.55563444
#   z: 0.0074963155
# }
# landmark {
#   x: 0.5864032
#   y: 0.5539575
#   z: 0.00547737
# }
# landmark {
#   x: 0.571414
#   y: 0.5490263
#   z: 0.006338111
# }
# landmark {
#   x: 0.5609111
#   y: 0.5430558
#   z: 0.00591749
# }
# landmark {
#   x: 0.6946688
#   y: 0.5673475
#   z: 0.14701726
# }
# landmark {
#   x: 0.57195413
#   y: 0.64837307
#   z: -0.036932074
# }
# landmark {
#   x: 0.54811394
#   y: 0.58580047
#   z: -0.045578033
# }
# landmark {
#   x: 0.55048037
#   y: 0.6418956
#   z: -0.0689036
# }
# landmark {
#   x: 0.5437681
#   y: 0.6533391
#   z: -0.0635067
# }
# landmark {
#   x: 0.551068
#   y: 0.64554
#   z: -0.062279917
# }
# landmark {
#   x: 0.5685556
#   y: 0.65490687
#   z: -0.032395422
# }
# landmark {
#   x: 0.5412175
#   y: 0.65547234
#   z: -0.06719298
# }
# landmark {
#   x: 0.54065007
#   y: 0.66022694
#   z: -0.051053673
# }
# landmark {
#   x: 0.5605888
#   y: 0.527794
#   z: 0.013566758
# }
# landmark {
#   x: 0.55217737
#   y: 0.5323132
#   z: 0.0052696806
# }
# landmark {
#   x: 0.54729366
#   y: 0.5350636
#   z: -0.0046787127
# }
# landmark {
#   x: 0.6274694
#   y: 0.5111721
#   z: 0.019535111
# }
# landmark {
#   x: 0.63507706
#   y: 0.5004147
#   z: 0.020016203
# }

# %%
import csv
import os
import numpy as np

# %%
num_coords=len(results.pose_landmarks.landmark)+len(results.face_landmarks.landmark)
num_coords
# Out:
# 501

# %%
# landmarks=['class']
# for val in range(1,num_coords+1):
#     landmarks +=['x{}'.format(val),'y{}'.format(val),'z{}'.format(val,'v{}'.format(val))]

# %%
# landmarks

# %%
# landmarks[-4]

# %%
# with open('coords.csv',mode='a',newline='')as f:
#     csv_writer=csv.writer(f,delimiter=',',quotechar='"',quoting=csv.QUOTE_MINIMAL)
#     csv_writer.writerow(landmarks)

# %%
# class_name="outofwindow"

# %%
# cap = cv2.VideoCapture(0)
# # Initiate holistic model
# with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
#     while cap.isOpened():
#         ret, frame = cap.read()
        
#         # Recolor Feed
#         image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#         image.flags.writeable = False        
        
#         # Make Detections
#         results = holistic.process(image)
#         # print(results.face_landmarks)
        
#         # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
#         # Recolor image back to BGR for rendering
#         image.flags.writeable = True   
#         image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
#         # 1. Draw face landmarks
#         mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
#                                  mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
#                                  mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
#                                  )
        
#         # 2. Right hand
#         mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
#                                  mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
#                                  mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
#                                  )

#         # 3. Left Hand
#         mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
#                                  mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
#                                  mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
#                                  )

#         # 4. Pose Detections
#         mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
#                                  mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
#                                  mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
#                                  )
#         # Export coordinates
#         try:
#             # Extract Pose landmarks
#             pose = results.pose_landmarks.landmark
#             pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
#             # Extract Face landmarks
#             face = results.face_landmarks.landmark
#             face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
#             # Concate rows
#             row = pose_row+face_row
            
#             # Append class name 
#             row.insert(0, class_name)
            
#             # Export to CSV
#             with open('coords.csv', mode='a', newline='') as f:
#                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                 csv_writer.writerow(row) 
            
#         except:
#             pass
                        
#         cv2.imshow('Raw Webcam Feed', image)

#         if cv2.waitKey(10) & 0xFF == ord('q'):
#             break

# cap.release()
# cv2.destroyAllWindows()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('coords.csv',sep=',', error_bad_lines=False, index_col=False, dtype='unicode')

# %%
# df

# %%
# df.head()

# %%
# df.tail()

# %%
# df[df['class']=='sad']

# %%
# df[df['class']=='Happy']

# %%
X = df.drop('class', axis=1) 
y = df['class']

# %%
# y

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
# df

# %%
X_train
# Out:
#                x1           y1            z1           x2           y2  \
# 1287  0.739616692  0.394585252  -0.569364488  0.999017596  0.718376815
# 1060  0.348796308  0.447317302  -0.938040733  0.999209583   0.38055256
# 99    0.622495115  0.520152509  -1.579429626  0.999448299  0.634511054
# 1312   0.73872745  0.403332233  -0.538118005  0.999411106  0.719089866
# 688   0.537546217  0.379330516  -1.135555983  0.999652743   0.56275785
# ...           ...          ...           ...          ...          ...
# 1228  0.798288882  0.433316559  -0.763227642  0.996139169  0.781287134
# 1077  0.339797825   0.45629546  -0.872697711  0.999339163  0.375622213
# 1318  0.739036381  0.403584868  -0.596311688  0.999465168  0.719375074
# 723   0.534677744  0.382611156  -1.161258221  0.999624312  0.561004043
# 815   0.336832583  0.480575919  -0.710166633  0.999391615  0.372376621
#
#                z2            x3           y3           z3           x4  ...  \
# 1287  0.333924413  -0.503813505    0.9985497  0.718278527  0.334447056  ...
# 1060  0.376610965  -0.941357791  0.997849584  0.400147915  0.373581469  ...
# 99    0.447049171  -1.523403525  0.998900056  0.647655129  0.444922894  ...
# 1312  0.341912866  -0.473112971  0.999151826  0.719506145  0.342186004  ...
# 688   0.314575374   -1.06319499  0.999176741  0.576865077  0.316032618  ...
# ...           ...           ...          ...          ...          ...  ...
# 1228   0.36894992  -0.687965035  0.993711114  0.780139089  0.368695855  ...
# 1077  0.383982927  -0.876815796  0.998214304  0.393689543  0.381443202  ...
# 1318  0.343112081  -0.528815567  0.999209344  0.719812989  0.343493044  ...
# 723     0.3181265  -1.086956739  0.999138653  0.575704932  0.319832683  ...
# 815   0.405230969  -0.737512708  0.998431325  0.389131665  0.401423723  ...
#
#               z665 x666         y666         z666          x667 y667  \
# 1287   0.004246681    0   0.72178036  0.299207538    0.03736528    0
# 1060  -0.006422492    0  0.404544383  0.373137385  -0.027311543    0
# 99    -0.009895252    0  0.679346919  0.448529363   0.028412567    0
# 1312  -0.001556487    0  0.717196047  0.301563531   0.022343529    0
# 688   -0.000600231    0  0.597347975  0.319121122   0.020066446    0
# ...            ...  ...          ...          ...           ...  ...
# 1228   0.001721582    0  0.778351724  0.309005201   0.032810241    0
# 1077  -0.007513298    0  0.396912009  0.378629893  -0.029552137    0
# 1318   0.009087604    0  0.737070024  0.323715717    0.04714584    0
# 723   -0.004346586    0  0.600674987  0.335085869   0.015478014    0
# 815   -0.013019484    0  0.385036767  0.402928382   -0.04700353    0
#
#              z667         x668          y668 z668
# 1287  0.722268581  0.295300424   0.039312817    0
# 1060  0.411791295  0.361784577  -0.029795686    0
# 99    0.684284389  0.439579189   0.030707413    0
# 1312  0.719138086  0.295515507   0.023843843    0
# 688   0.603199482  0.313432723   0.020993127    0
# ...           ...          ...           ...  ...
# 1228  0.778587639  0.304406464   0.034773335    0
# 1077  0.404209852  0.367570341  -0.032149039    0
# 1318  0.736982286  0.318399847   0.050102271    0
# 723   0.606392503  0.329515159   0.016154962    0
# 815   0.392265409  0.392712712  -0.050677646    0
#
# [1159 rows x 2004 columns]

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression(max_iter=2100)),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier(max_iter=2100)),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
pipelines
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression(max_iter=2100))]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier(max_iter=2100))]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
type(X_train['x1'][1128])
# Out:
# str

# %%
fit_models = {}
X_train=X_train.astype(float)
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression(max_iter=2100))]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier(max_iter=2100))]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['sad', 'moving left', 'Happy', 'moving left', 'sad', 'sad',
#        'moving right', 'sad', 'Happy', 'sad', 'moving left',
#        'moving right', 'Confused', 'sad', 'sad', 'Confused', 'Happy',
#        'Confused', 'sad', 'moving left', 'Happy', 'sad', 'Confused',
#        'Confused', 'sad', 'Happy', 'moving right', 'outofwindow', 'Happy',
#        'moving right', 'moving right', 'Confused', 'moving right',
#        'Confused', 'sad', 'moving right', 'moving right', 'sad',
#        'moving right', 'Happy', 'Confused', 'moving left', 'sad',
#        'Confused', 'sad', 'sad', 'Confused', 'sad', 'moving right',
#        'Happy', 'moving left', 'sad', 'moving right', 'sad', 'sad',
#        'moving left', 'Confused', 'Happy', 'Confused', 'moving right',
#        'Confused', 'Happy', 'sad', 'moving right', 'moving left', 'sad',
#        'Happy', 'Happy', 'Confused', 'Happy', 'moving left', 'Confused',
#        'Confused', 'sad', 'Happy', 'moving left', 'Happy', 'outofwindow',
#        'Confused', 'moving left', 'sad', 'Confused', 'sad',
#        'moving right', 'Happy', 'sad', 'moving right', 'moving left',
#        'moving right', 'Happy', 'moving right', 'moving right',
#        'moving right', 'moving left', 'Confused', 'moving left',
#        'moving right', 'moving right', 'moving left', 'sad', 'Happy',
#        'Confused', 'sad', 'moving right', 'moving right', 'Confused',
#        'sad', 'moving left', 'Confused', 'sad', 'sad', 'moving left',
#        'sad', 'sad', 'Happy', 'sad', 'moving left', 'Confused', 'Happy',
#        'moving right', 'moving right', 'Happy', 'moving right',
#        'Confused', 'moving right', 'Confused', 'Happy', 'sad',
#        'moving right', 'sad', 'Confused', 'sad', 'moving left', 'Happy',
#        'moving right', 'sad', 'moving right', 'Happy', 'Confused',
#        'moving left', 'sad', 'moving right', 'Happy', 'moving right',
#        'Confused', 'moving right', 'moving right', 'moving right',
#        'moving left', 'moving right', 'sad', 'moving right',
#        'moving right', 'moving right', 'sad', 'moving right',
#        'moving right', 'Confused', 'Confused', 'moving left', 'sad',
#        'sad', 'Confused', 'moving left', 'sad', 'Confused', 'sad', 'sad',
#        'Happy', 'moving left', 'moving right', 'Confused', 'sad',
#        'moving right', 'Confused', 'Confused', 'sad', 'sad', 'Confused',
#        'Confused', 'Confused', 'outofwindow', 'moving left', 'sad',
#        'moving right', 'sad', 'Confused', 'Happy', 'moving right',
#        'moving right', 'Confused', 'Confused', 'Happy', 'Confused',
#        'Confused', 'sad', 'sad', 'Happy', 'Happy', 'sad', 'moving right',
#        'Happy', 'Confused', 'moving left', 'sad', 'Happy', 'moving right',
#        'sad', 'Confused', 'moving right', 'sad', 'Happy', 'moving left',
#        'moving left', 'sad', 'moving left', 'Happy', 'Confused',
#        'moving left', 'moving right', 'Confused', 'sad', 'Confused',
#        'Happy', 'sad', 'Happy', 'moving right', 'sad', 'moving right',
#        'sad', 'moving right', 'Confused', 'moving right', 'sad', 'sad',
#        'moving right', 'Happy', 'sad', 'Happy', 'moving right',
#        'moving right', 'Confused', 'moving right', 'moving right',
#        'moving right', 'moving right', 'sad', 'moving right', 'Confused',
#        'moving left', 'moving right', 'moving right', 'Happy',
#        'moving left', 'Happy', 'moving right', 'sad', 'Confused',
#        'Confused', 'sad', 'sad', 'Happy', 'Confused', 'Confused',
#        'moving right', 'Happy', 'Happy', 'Confused', 'Confused',
#        'moving left', 'moving left', 'sad', 'Confused', 'moving left',
#        'Confused', 'sad', 'sad', 'Happy', 'moving right', 'Confused',
#        'sad', 'sad', 'Happy', 'sad', 'sad', 'sad', 'moving left', 'Happy',
#        'moving right', 'moving right', 'Happy', 'sad', 'Happy',
#        'moving right', 'sad', 'sad', 'moving right', 'sad',
#        'moving right', 'sad', 'moving right', 'moving right',
#        'moving right', 'sad', 'sad', 'Confused', 'sad', 'Confused',
#        'Happy', 'sad', 'moving right', 'sad', 'sad', 'moving right',
#        'sad', 'moving right', 'moving right', 'moving right', 'Confused',
#        'moving right', 'moving left', 'moving right', 'sad', 'Happy',
#        'Happy', 'moving right', 'Happy', 'Confused', 'moving left', 'sad',
#        'Happy', 'Confused', 'sad', 'Confused', 'sad', 'sad', 'Confused',
#        'sad', 'Happy', 'moving right', 'sad', 'sad', 'Happy', 'sad',
#        'moving right', 'moving right', 'Confused', 'Confused',
#        'moving right', 'moving right', 'sad', 'moving right',
#        'moving left', 'moving right', 'Happy', 'Confused', 'sad', 'Happy',
#        'sad', 'Happy', 'moving right', 'Happy', 'sad', 'sad', 'Confused',
#        'sad', 'moving left', 'moving right', 'moving right',
#        'moving right', 'Happy', 'sad', 'moving right', 'moving right',
#        'moving right', 'Happy', 'Happy', 'moving right', 'Happy', 'sad',
#        'Happy', 'Confused', 'Happy', 'Confused', 'Happy', 'sad', 'Happy',
#        'moving right', 'sad', 'Confused', 'moving left', 'Happy', 'sad',
#        'Happy', 'sad', 'sad', 'sad', 'moving right', 'Happy', 'Confused',
#        'sad', 'Happy', 'sad', 'Confused', 'Happy', 'Happy',
#        'moving right', 'moving right', 'sad', 'moving right', 'sad',
#        'moving right', 'sad', 'sad', 'sad', 'moving right',
#        'moving right', 'Happy', 'sad', 'Happy', 'Happy', 'moving left',
#        'sad', 'Confused', 'sad', 'moving right', 'Happy', 'moving right',
#        'moving right', 'sad', 'moving right', 'sad', 'Confused',
#        'moving left', 'moving right', 'Confused', 'sad', 'outofwindow',
#        'Happy', 'moving right', 'moving right', 'moving left', 'Happy',
#        'Happy', 'moving right', 'Happy', 'Happy', 'sad', 'Happy', 'sad',
#        'moving right', 'sad', 'moving left', 'moving right', 'Happy',
#        'Confused', 'sad', 'sad', 'Confused', 'Confused', 'sad', 'sad',
#        'sad', 'Happy', 'Happy', 'Confused', 'sad', 'sad', 'sad',
#        'Confused', 'sad', 'moving left', 'Confused', 'sad', 'sad',
#        'moving left', 'Confused', 'sad', 'moving right', 'moving right',
#        'sad', 'sad', 'sad', 'moving left', 'moving right', 'Happy',
#        'Confused', 'sad', 'sad', 'sad', 'Confused', 'sad', 'moving right',
#        'Confused', 'outofwindow', 'Happy', 'sad', 'Confused'],
#       dtype='<U12')

# %%
from sklearn.metrics import accuracy_score 
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 0.9959839357429718
# rc 0.9939759036144579
# rf 0.9959839357429718
# gb 0.9959839357429718

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['sad', 'moving left', 'Happy', 'moving left', 'sad', 'sad',
#        'moving right', 'sad', 'Happy', 'sad', 'moving left',
#        'moving right', 'Confused', 'sad', 'sad', 'Confused', 'Happy',
#        'Confused', 'sad', 'moving left', 'Happy', 'sad', 'Confused',
#        'Confused', 'sad', 'Happy', 'moving right', 'outofwindow', 'Happy',
#        'moving right', 'moving right', 'Confused', 'moving right',
#        'Confused', 'sad', 'moving right', 'moving right', 'sad',
#        'moving right', 'Happy', 'Confused', 'moving left', 'sad',
#        'Confused', 'sad', 'sad', 'Confused', 'sad', 'moving right',
#        'Happy', 'moving left', 'sad', 'moving right', 'sad', 'sad',
#        'moving left', 'Confused', 'Happy', 'Confused', 'moving right',
#        'Confused', 'Happy', 'sad', 'moving right', 'moving left', 'sad',
#        'Happy', 'Happy', 'Confused', 'Happy', 'moving left', 'Confused',
#        'Confused', 'sad', 'Happy', 'moving left', 'Happy', 'Happy',
#        'Confused', 'moving left', 'sad', 'Confused', 'sad',
#        'moving right', 'Happy', 'sad', 'moving right', 'moving left',
#        'moving right', 'outofwindow', 'moving right', 'moving right',
#        'moving right', 'moving left', 'Confused', 'moving left',
#        'moving right', 'moving right', 'moving left', 'sad', 'Happy',
#        'Confused', 'sad', 'moving right', 'moving right', 'Confused',
#        'sad', 'moving left', 'Confused', 'sad', 'sad', 'moving left',
#        'sad', 'sad', 'Happy', 'sad', 'moving left', 'Confused', 'Happy',
#        'moving right', 'moving right', 'Happy', 'moving right',
#        'Confused', 'moving right', 'Confused', 'Happy', 'sad',
#        'moving right', 'sad', 'Confused', 'sad', 'moving left', 'Happy',
#        'moving right', 'sad', 'moving right', 'Happy', 'Confused',
#        'moving left', 'sad', 'moving right', 'Happy', 'moving right',
#        'Confused', 'moving right', 'moving right', 'moving right',
#        'moving left', 'moving right', 'sad', 'moving right',
#        'moving right', 'moving right', 'sad', 'moving right',
#        'moving right', 'Confused', 'Confused', 'moving left', 'sad',
#        'sad', 'Confused', 'moving left', 'sad', 'Confused', 'sad', 'sad',
#        'Happy', 'moving left', 'moving right', 'Confused', 'sad',
#        'moving right', 'Confused', 'Confused', 'sad', 'sad', 'Confused',
#        'Confused', 'Confused', 'outofwindow', 'moving left', 'sad',
#        'moving right', 'sad', 'Confused', 'Happy', 'moving right',
#        'moving right', 'Confused', 'Confused', 'Happy', 'Confused',
#        'Confused', 'sad', 'sad', 'Happy', 'Happy', 'sad', 'moving right',
#        'Happy', 'Confused', 'moving left', 'sad', 'Happy', 'moving right',
#        'sad', 'Confused', 'moving right', 'sad', 'Happy', 'moving left',
#        'moving left', 'sad', 'moving left', 'Happy', 'Confused',
#        'moving left', 'moving right', 'Confused', 'sad', 'Confused',
#        'Happy', 'sad', 'Happy', 'moving right', 'sad', 'moving right',
#        'sad', 'moving right', 'Confused', 'moving right', 'sad', 'sad',
#        'moving right', 'Happy', 'sad', 'Happy', 'moving right',
#        'moving right', 'Confused', 'moving right', 'moving right',
#        'moving right', 'moving right', 'sad', 'moving right', 'Confused',
#        'moving left', 'moving right', 'moving right', 'Happy',
#        'moving left', 'Happy', 'moving right', 'sad', 'Confused',
#        'Confused', 'sad', 'sad', 'Happy', 'Confused', 'Confused',
#        'moving right', 'Happy', 'Happy', 'Confused', 'Confused',
#        'moving left', 'moving left', 'sad', 'Confused', 'moving left',
#        'Confused', 'sad', 'sad', 'Happy', 'moving right', 'Confused',
#        'sad', 'sad', 'Happy', 'sad', 'sad', 'sad', 'moving left', 'Happy',
#        'moving right', 'moving right', 'Happy', 'sad', 'Happy',
#        'moving right', 'sad', 'sad', 'moving right', 'sad',
#        'moving right', 'sad', 'moving right', 'moving right',
#        'moving right', 'sad', 'sad', 'Confused', 'sad', 'Confused',
#        'Happy', 'sad', 'moving right', 'sad', 'sad', 'moving right',
#        'sad', 'moving right', 'moving right', 'moving right', 'Confused',
#        'moving right', 'moving left', 'moving right', 'sad', 'Happy',
#        'Happy', 'moving right', 'Happy', 'Confused', 'moving left', 'sad',
#        'Happy', 'Confused', 'sad', 'Confused', 'sad', 'sad', 'Confused',
#        'sad', 'Happy', 'moving right', 'sad', 'sad', 'Happy', 'sad',
#        'moving right', 'moving right', 'Confused', 'Confused',
#        'moving right', 'moving right', 'sad', 'moving right',
#        'moving left', 'moving right', 'Happy', 'Confused', 'sad', 'Happy',
#        'sad', 'Happy', 'moving right', 'Happy', 'sad', 'sad', 'Confused',
#        'sad', 'moving left', 'moving right', 'moving right',
#        'moving right', 'Happy', 'sad', 'moving right', 'moving right',
#        'outofwindow', 'Happy', 'Happy', 'moving right', 'Happy', 'sad',
#        'Happy', 'Confused', 'Happy', 'Confused', 'Happy', 'sad', 'Happy',
#        'moving right', 'sad', 'Confused', 'moving left', 'Happy', 'sad',
#        'Happy', 'sad', 'sad', 'sad', 'moving right', 'Happy', 'Confused',
#        'sad', 'Happy', 'sad', 'Confused', 'Happy', 'Happy',
#        'moving right', 'moving right', 'sad', 'moving right', 'sad',
#        'moving right', 'sad', 'sad', 'sad', 'moving right',
#        'moving right', 'Happy', 'sad', 'Happy', 'outofwindow',
#        'moving left', 'sad', 'Confused', 'sad', 'moving right', 'Happy',
#        'moving right', 'moving right', 'sad', 'moving right', 'sad',
#        'Confused', 'moving left', 'moving right', 'Confused', 'sad',
#        'Confused', 'Happy', 'moving right', 'moving right', 'moving left',
#        'Happy', 'Happy', 'moving right', 'Happy', 'Happy', 'sad', 'Happy',
#        'sad', 'moving right', 'sad', 'moving left', 'moving right',
#        'Happy', 'Confused', 'sad', 'sad', 'Confused', 'Confused', 'sad',
#        'sad', 'sad', 'Happy', 'Happy', 'Confused', 'sad', 'sad', 'sad',
#        'Confused', 'sad', 'moving left', 'Confused', 'sad', 'sad',
#        'moving left', 'Confused', 'sad', 'moving right', 'moving right',
#        'sad', 'sad', 'sad', 'moving left', 'moving right', 'Happy',
#        'Confused', 'sad', 'sad', 'sad', 'Confused', 'sad', 'moving right',
#        'Confused', 'outofwindow', 'Happy', 'sad', 'Confused'],
#       dtype=object)

# %%
y_test
# Out:
# 237             sad
# 1226    moving left
# 662           Happy
# 1279    moving left
# 139             sad
#            ...
# 1551       Confused
# 1632    outofwindow
# 537           Happy
# 71              sad
# 1366       Confused
# Name: class, Length: 498, dtype: object

# %%
with open('body_language.pkl', 'wb') as f:
    pickle.dump(fit_models, f)

# %%
with open('body_language.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression(max_iter=2100))]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier(max_iter=2100))]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
import datetime
ans=[]
count=0
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
            
            # Append class name 
#             row.insert(0, class_name)
            
#             # Export to CSV
#             with open('coords.csv', mode='a', newline='') as f:
#                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                 csv_writer.writerow(row)

            #make detection
            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class, body_language_prob)
            if len(ans)==0 or ans[-1][1]!=body_language_class:
                now = datetime.datetime.now()
                ans.append([now.strftime('%Y-%m-%d  %H:%M:%S'),body_language_class])
            
            for outofwindow in body_language_class:
                if count<=4:
                    alert("WARNING!: FACE NOT DETECTED")
                    count=count+1
                else:
                    cap.isClosed()
                    alert("END OF METTING")
                    
            
            
            
            
            # Grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            
            

            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
tuple(np.multiply(np.array((results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y)), [640,480]).astype(int))
# Out:
# (445, 175)

# %%
print(body_language_class)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-89-4c945e262009> in <module>
# ----> 1 print(body_language_class)
#
# NameError: name 'body_language_class' is not defined

# %%
print(ans)
# Out:
# []

# %%
file=open('body_language.txt','w')
for item in ans:
    file.write(item[0]+"-"+item[1]+"\n")
file.close()

# %%
print(ans)
