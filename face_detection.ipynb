# %%
# import numpy as np
# import cv2

# %%
# capture=cv2.VideoCapture(0)

# fourcc=cv2.VideoWriter_fourcc(*'XVID')
# out=cv2.VideoWriter('Intern/videos/interview.mp4',fourcc,20.0,(640,480))

# while(capture.isOpened()):
#     ret,frame=capture.read()
#     if(ret==True):
#         out.write(frame)
#         cv2.imshow('output',frame)
#         if(cv2.waitKey(1) & 0xFF==ord('q')):
#             break
#     else:
#         break
# capture.release()
# cv2.destroyAllWindows()

# %%
# !pip install mediapipe opencv-python

# %%
# !pip install opencv-contrib-python

# %%
# !pip install pandas scikit-learn

# %%
import mediapipe as mp
import cv2

# %%
mp_drawing=mp.solutions.drawing_utils
mp_holistic=mp.solutions.holistic

# %%
cap = cv2.VideoCapture(0)
# fourcc=cv2.VideoWriter_fourcc(*'XVID')


# directory='Intern/videos'

# video_files = [f for f in os.listdir(directory) if f.endswith('.mp4')]

# current_time = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
# output_file = f'Intern/videos/interview_{current_time}.mp4'

# print(video_files)

# out=cv2.VideoWriter(output_file,fourcc,20.0,(640,480))


# for filename in video_files:
#   capt=cv2.VideoCapture(filename)

# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret,frame=cap.read()
    
    
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
results.face_landmarks.landmark[0].visibility
# Out:
# 0.0

# %%
results.face_landmarks
# Out:
# landmark {
#   x: 0.5736444
#   y: 0.7387699
#   z: -0.03956671
# }
# landmark {
#   x: 0.58111805
#   y: 0.6891102
#   z: -0.048862834
# }
# landmark {
#   x: 0.5765182
#   y: 0.71066636
#   z: -0.031231292
# }
# landmark {
#   x: 0.57425505
#   y: 0.6511152
#   z: -0.029438334
# }
# landmark {
#   x: 0.5825464
#   y: 0.6751142
#   z: -0.04942525
# }
# landmark {
#   x: 0.5828293
#   y: 0.66053694
#   z: -0.042398203
# }
# landmark {
#   x: 0.5822471
#   y: 0.62916505
#   z: -0.0079078395
# }
# landmark {
#   x: 0.5095351
#   y: 0.62791204
#   z: 0.016237339
# }
# landmark {
#   x: 0.5840886
#   y: 0.5993243
#   z: 0.0050757546
# }
# landmark {
#   x: 0.5858834
#   y: 0.5811335
#   z: 0.0079070255
# }
# landmark {
#   x: 0.5883008
#   y: 0.5255057
#   z: 0.033745877
# }
# landmark {
#   x: 0.5728462
#   y: 0.74578196
#   z: -0.03970072
# }
# landmark {
#   x: 0.57163537
#   y: 0.7528505
#   z: -0.037509512
# }
# landmark {
#   x: 0.5705163
#   y: 0.75734866
#   z: -0.0342492
# }
# landmark {
#   x: 0.569888
#   y: 0.76623505
#   z: -0.035230182
# }
# landmark {
#   x: 0.5695426
#   y: 0.7718534
#   z: -0.037589543
# }
# landmark {
#   x: 0.56889445
#   y: 0.77975
#   z: -0.04033059
# }
# landmark {
#   x: 0.56792396
#   y: 0.7888849
#   z: -0.039848562
# }
# landmark {
#   x: 0.56554633
#   y: 0.8057943
#   z: -0.03284702
# }
# landmark {
#   x: 0.57944864
#   y: 0.6982802
#   z: -0.045772456
# }
# landmark {
#   x: 0.5702562
#   y: 0.69978184
#   z: -0.035760947
# }
# landmark {
#   x: 0.47107545
#   y: 0.58286655
#   z: 0.06794827
# }
# landmark {
#   x: 0.53522724
#   y: 0.64142686
#   z: 0.008690711
# }
# landmark {
#   x: 0.52572924
#   y: 0.6414149
#   z: 0.007911243
# }
# landmark {
#   x: 0.51671565
#   y: 0.6394355
#   z: 0.009397046
# }
# landmark {
#   x: 0.50449157
#   y: 0.63240266
#   z: 0.015961641
# }
# landmark {
#   x: 0.5435654
#   y: 0.6385504
#   z: 0.011794135
# }
# landmark {
#   x: 0.5285339
#   y: 0.60400903
#   z: 0.008606246
# }
# landmark {
#   x: 0.5376867
#   y: 0.6065829
#   z: 0.010997147
# }
# landmark {
#   x: 0.5189786
#   y: 0.6045582
#   z: 0.010042138
# }
# landmark {
#   x: 0.511592
#   y: 0.6090216
#   z: 0.012569014
# }
# landmark {
#   x: 0.49521777
#   y: 0.6397116
#   z: 0.018033989
# }
# landmark {
#   x: 0.5258368
#   y: 0.8258116
#   z: -0.033728566
# }
# landmark {
#   x: 0.5066298
#   y: 0.6251546
#   z: 0.019407162
# }
# landmark {
#   x: 0.46181396
#   y: 0.6391922
#   z: 0.055447392
# }
# landmark {
#   x: 0.48444742
#   y: 0.6305156
#   z: 0.027960846
# }
# landmark {
#   x: 0.5269071
#   y: 0.6881739
#   z: -0.012974555
# }
# landmark {
#   x: 0.562209
#   y: 0.7353612
#   z: -0.039637826
# }
# landmark {
#   x: 0.5616996
#   y: 0.7520234
#   z: -0.038005326
# }
# landmark {
#   x: 0.54867494
#   y: 0.74106556
#   z: -0.03728257
# }
# landmark {
#   x: 0.5393662
#   y: 0.74947363
#   z: -0.03338292
# }
# landmark {
#   x: 0.55220467
#   y: 0.7539249
#   z: -0.03636227
# }
# landmark {
#   x: 0.5446364
#   y: 0.7575165
#   z: -0.03206085
# }
# landmark {
#   x: 0.52363956
#   y: 0.777279
#   z: -0.027062897
# }
# landmark {
#   x: 0.5734552
#   y: 0.6879527
#   z: -0.049012966
# }
# landmark {
#   x: 0.57346314
#   y: 0.6746337
#   z: -0.049478263
# }
# landmark {
#   x: 0.49667278
#   y: 0.59113854
#   z: 0.018461393
# }
# landmark {
#   x: 0.54807085
#   y: 0.658822
#   z: -0.0038871462
# }
# landmark {
#   x: 0.54818237
#   y: 0.6895809
#   z: -0.030686239
# }
# landmark {
#   x: 0.54726326
#   y: 0.6841822
#   z: -0.026975721
# }
# landmark {
#   x: 0.49567643
#   y: 0.6866714
#   z: -0.005295828
# }
# landmark {
#   x: 0.57405573
#   y: 0.6611745
#   z: -0.041110974
# }
# landmark {
#   x: 0.5234085
#   y: 0.57526535
#   z: 0.009278719
# }
# landmark {
#   x: 0.5086987
#   y: 0.5798787
#   z: 0.013841747
# }
# landmark {
#   x: 0.48590684
#   y: 0.555602
#   z: 0.057437293
# }
# landmark {
#   x: 0.5641788
#   y: 0.5925406
#   z: 0.005235056
# }
# landmark {
#   x: 0.54531753
#   y: 0.6123812
#   z: 0.014124609
# }
# landmark {
#   x: 0.5178411
#   y: 0.76309085
#   z: -0.023833416
# }
# landmark {
#   x: 0.4564186
#   y: 0.77529556
#   z: 0.04797922
# }
# landmark {
#   x: 0.55467176
#   y: 0.6982307
#   z: -0.027726483
# }
# landmark {
#   x: 0.5626236
#   y: 0.70397377
#   z: -0.028368039
# }
# landmark {
#   x: 0.5290643
#   y: 0.76425385
#   z: -0.023931129
# }
# landmark {
#   x: 0.533646
#   y: 0.7641084
#   z: -0.025497833
# }
# landmark {
#   x: 0.50308317
#   y: 0.5710783
#   z: 0.019778186
# }
# landmark {
#   x: 0.54685307
#   y: 0.69770306
#   z: -0.027173465
# }
# landmark {
#   x: 0.5417237
#   y: 0.5784162
#   z: 0.00641436
# }
# landmark {
#   x: 0.54119205
#   y: 0.56686515
#   z: 0.007189804
# }
# landmark {
#   x: 0.5327283
#   y: 0.52321744
#   z: 0.035165023
# }
# landmark {
#   x: 0.49479136
#   y: 0.56265545
#   z: 0.036238626
# }
# landmark {
#   x: 0.53823256
#   y: 0.5437674
#   z: 0.021323277
# }
# landmark {
#   x: 0.48997027
#   y: 0.58651066
#   z: 0.027151464
# }
# landmark {
#   x: 0.48074377
#   y: 0.58505565
#   z: 0.04662773
# }
# landmark {
#   x: 0.5618145
#   y: 0.74413747
#   z: -0.040024523
# }
# landmark {
#   x: 0.55081636
#   y: 0.7481109
#   z: -0.037539806
# }
# landmark {
#   x: 0.542155
#   y: 0.7534133
#   z: -0.0336264
# }
# landmark {
#   x: 0.5568826
#   y: 0.70188606
#   z: -0.025655393
# }
# landmark {
#   x: 0.53153056
#   y: 0.7643993
#   z: -0.024624541
# }
# landmark {
#   x: 0.5353875
#   y: 0.76623905
#   z: -0.030049223
# }
# landmark {
#   x: 0.53436935
#   y: 0.76370454
#   z: -0.025529228
# }
# landmark {
#   x: 0.56150144
#   y: 0.69031495
#   z: -0.038041294
# }
# landmark {
#   x: 0.5459572
#   y: 0.7582057
#   z: -0.030835915
# }
# landmark {
#   x: 0.55341136
#   y: 0.756424
#   z: -0.03331215
# }
# landmark {
#   x: 0.56180805
#   y: 0.7562115
#   z: -0.0349596
# }
# landmark {
#   x: 0.5529572
#   y: 0.80315286
#   z: -0.034396406
# }
# landmark {
#   x: 0.55625355
#   y: 0.78586245
#   z: -0.040937465
# }
# landmark {
#   x: 0.5579343
#   y: 0.77661324
#   z: -0.04104789
# }
# landmark {
#   x: 0.5595087
#   y: 0.7688648
#   z: -0.03813538
# }
# landmark {
#   x: 0.56058717
#   y: 0.76456594
#   z: -0.03572318
# }
# landmark {
#   x: 0.5446088
#   y: 0.76374185
#   z: -0.030936452
# }
# landmark {
#   x: 0.5430567
#   y: 0.7651098
#   z: -0.0331411
# }
# landmark {
#   x: 0.5404327
#   y: 0.7686126
#   z: -0.03570186
# }
# landmark {
#   x: 0.5377302
#   y: 0.77373207
#   z: -0.035113137
# }
# landmark {
#   x: 0.53236675
#   y: 0.73506325
#   z: -0.028077831
# }
# landmark {
#   x: 0.4502891
#   y: 0.70802206
#   z: 0.076590225
# }
# landmark {
#   x: 0.5779932
#   y: 0.7038668
#   z: -0.035903737
# }
# landmark {
#   x: 0.53970087
#   y: 0.7645334
#   z: -0.027707264
# }
# landmark {
#   x: 0.53799343
#   y: 0.7646265
#   z: -0.02929936
# }
# landmark {
#   x: 0.5650815
#   y: 0.71029884
#   z: -0.030629292
# }
# landmark {
#   x: 0.5490072
#   y: 0.7079839
#   z: -0.021945601
# }
# landmark {
#   x: 0.56395596
#   y: 0.70731723
#   z: -0.029396137
# }
# landmark {
#   x: 0.5366645
#   y: 0.66590375
#   z: -0.004337417
# }
# landmark {
#   x: 0.5202842
#   y: 0.6724841
#   z: -0.0052286796
# }
# landmark {
#   x: 0.54465485
#   y: 0.6916753
#   z: -0.023444548
# }
# landmark {
#   x: 0.5057719
#   y: 0.53497565
#   z: 0.045055095
# }
# landmark {
#   x: 0.5132188
#   y: 0.5479546
#   z: 0.027890341
# }
# landmark {
#   x: 0.52061343
#   y: 0.5642653
#   z: 0.013320871
# }
# landmark {
#   x: 0.530781
#   y: 0.7866562
#   z: -0.03137189
# }
# landmark {
#   x: 0.5634016
#   y: 0.573694
#   z: 0.00551444
# }
# landmark {
#   x: 0.5618541
#   y: 0.546777
#   z: 0.018585173
# }
# landmark {
#   x: 0.5592295
#   y: 0.5210265
#   z: 0.031102173
# }
# landmark {
#   x: 0.50881064
#   y: 0.636752
#   z: 0.012550613
# }
# landmark {
#   x: 0.483436
#   y: 0.64813095
#   z: 0.019761175
# }
# landmark {
#   x: 0.54918665
#   y: 0.63511395
#   z: 0.014348181
# }
# landmark {
#   x: 0.4986155
#   y: 0.6127046
#   z: 0.01945383
# }
# landmark {
#   x: 0.5563245
#   y: 0.65015495
#   z: -0.0045024515
# }
# landmark {
#   x: 0.55570835
#   y: 0.68216145
#   z: -0.037192803
# }
# landmark {
#   x: 0.4708275
#   y: 0.65847415
#   z: 0.025409846
# }
# landmark {
#   x: 0.49008048
#   y: 0.6560229
#   z: 0.010087227
# }
# landmark {
#   x: 0.5029647
#   y: 0.6604039
#   z: 0.0025581808
# }
# landmark {
#   x: 0.5219653
#   y: 0.6604372
#   z: 0.001434335
# }
# landmark {
#   x: 0.5361283
#   y: 0.656902
#   z: 0.0023512533
# }
# landmark {
#   x: 0.54733634
#   y: 0.6514704
#   z: 0.003106424
# }
# landmark {
#   x: 0.57253754
#   y: 0.6316721
#   z: -0.006752326
# }
# landmark {
#   x: 0.47012198
#   y: 0.68597263
#   z: 0.016347947
# }
# landmark {
#   x: 0.48994216
#   y: 0.6100317
#   z: 0.023717057
# }
# landmark {
#   x: 0.5752177
#   y: 0.69723696
#   z: -0.046026755
# }
# landmark {
#   x: 0.54901004
#   y: 0.669335
#   z: -0.011000953
# }
# landmark {
#   x: 0.45419312
#   y: 0.64596915
#   z: 0.08506132
# }
# landmark {
#   x: 0.55602926
#   y: 0.6442074
#   z: 0.0047174487
# }
# landmark {
#   x: 0.5425254
#   y: 0.6947866
#   z: -0.015025802
# }
# landmark {
#   x: 0.50240535
#   y: 0.6246499
#   z: 0.02049476
# }
# landmark {
#   x: 0.55487645
#   y: 0.67595875
#   z: -0.03230638
# }
# landmark {
#   x: 0.45123687
#   y: 0.7409842
#   z: 0.06485861
# }
# landmark {
#   x: 0.5495268
#   y: 0.63098156
#   z: 0.017503383
# }
# landmark {
#   x: 0.56462336
#   y: 0.66680133
#   z: -0.03812143
# }
# landmark {
#   x: 0.48179728
#   y: 0.79789406
#   z: -0.0021411474
# }
# landmark {
#   x: 0.4775819
#   y: 0.819648
#   z: 0.009892848
# }
# landmark {
#   x: 0.45634478
#   y: 0.6964881
#   z: 0.04584976
# }
# landmark {
#   x: 0.4698062
#   y: 0.78031653
#   z: 0.011044157
# }
# landmark {
#   x: 0.47096166
#   y: 0.6107346
#   z: 0.053969707
# }
# landmark {
#   x: 0.5214445
#   y: 0.8425438
#   z: -0.0325017
# }
# landmark {
#   x: 0.57478833
#   y: 0.70290834
#   z: -0.03569767
# }
# landmark {
#   x: 0.5392436
#   y: 0.679265
#   z: -0.011015312
# }
# landmark {
#   x: 0.47457877
#   y: 0.6341455
#   z: 0.035393126
# }
# landmark {
#   x: 0.51859105
#   y: 0.6320102
#   z: 0.011340938
# }
# landmark {
#   x: 0.52664596
#   y: 0.6341155
#   z: 0.010094781
# }
# landmark {
#   x: 0.53246593
#   y: 0.7689646
#   z: -0.029373582
# }
# landmark {
#   x: 0.46939546
#   y: 0.7143981
#   z: 0.01236513
# }
# landmark {
#   x: 0.5371474
#   y: 0.8669837
#   z: -0.031905048
# }
# landmark {
#   x: 0.5060476
#   y: 0.8478523
#   z: -0.014831626
# }
# landmark {
#   x: 0.49262857
#   y: 0.8363019
#   z: -0.004222303
# }
# landmark {
#   x: 0.5872673
#   y: 0.552726
#   z: 0.02037719
# }
# landmark {
#   x: 0.55811614
#   y: 0.8724618
#   z: -0.03184202
# }
# landmark {
#   x: 0.53446835
#   y: 0.6344022
#   z: 0.011208339
# }
# landmark {
#   x: 0.5417677
#   y: 0.6331503
#   z: 0.0138290385
# }
# landmark {
#   x: 0.54660165
#   y: 0.6321211
#   z: 0.016862964
# }
# landmark {
#   x: 0.4817322
#   y: 0.60868627
#   z: 0.032504965
# }
# landmark {
#   x: 0.54276603
#   y: 0.62488294
#   z: 0.014028538
# }
# landmark {
#   x: 0.5352892
#   y: 0.62264705
#   z: 0.011754413
# }
# landmark {
#   x: 0.52837974
#   y: 0.62121046
#   z: 0.011052142
# }
# landmark {
#   x: 0.5205416
#   y: 0.62136936
#   z: 0.011926262
# }
# landmark {
#   x: 0.5145246
#   y: 0.62275684
#   z: 0.0136788245
# }
# landmark {
#   x: 0.46111667
#   y: 0.61121416
#   z: 0.07914516
# }
# landmark {
#   x: 0.51328087
#   y: 0.6297732
#   z: 0.0137962075
# }
# landmark {
#   x: 0.57535493
#   y: 0.7202557
#   z: -0.031651538
# }
# landmark {
#   x: 0.54263824
#   y: 0.7263242
#   z: -0.028871622
# }
# landmark {
#   x: 0.5549994
#   y: 0.6946581
#   z: -0.029731859
# }
# landmark {
#   x: 0.5625129
#   y: 0.720385
#   z: -0.033169314
# }
# landmark {
#   x: 0.582373
#   y: 0.6158307
#   z: 0.0020369024
# }
# landmark {
#   x: 0.49433506
#   y: 0.81552374
#   z: -0.012681895
# }
# landmark {
#   x: 0.5071742
#   y: 0.82924604
#   z: -0.022432573
# }
# landmark {
#   x: 0.5393734
#   y: 0.83639205
#   z: -0.041130487
# }
# landmark {
#   x: 0.5493575
#   y: 0.6771976
#   z: -0.018107312
# }
# landmark {
#   x: 0.501031
#   y: 0.79636484
#   z: -0.01902593
# }
# landmark {
#   x: 0.5130078
#   y: 0.8122286
#   z: -0.025965227
# }
# landmark {
#   x: 0.5066372
#   y: 0.76525223
#   z: -0.020795029
# }
# landmark {
#   x: 0.46962005
#   y: 0.73934585
#   z: 0.010313256
# }
# landmark {
#   x: 0.49194592
#   y: 0.7691567
#   z: -0.01321127
# }
# landmark {
#   x: 0.46018195
#   y: 0.75561863
#   z: 0.02699933
# }
# landmark {
#   x: 0.5131864
#   y: 0.7375182
#   z: -0.02076334
# }
# landmark {
#   x: 0.5571374
#   y: 0.6593113
#   z: -0.013178764
# }
# landmark {
#   x: 0.5587019
#   y: 0.687443
#   z: -0.039433982
# }
# landmark {
#   x: 0.55105126
#   y: 0.6934776
#   z: -0.031950764
# }
# landmark {
#   x: 0.56453365
#   y: 0.6772151
#   z: -0.0434763
# }
# landmark {
#   x: 0.55330396
#   y: 0.6058636
#   z: 0.013081218
# }
# landmark {
#   x: 0.539523
#   y: 0.5954412
#   z: 0.010827812
# }
# landmark {
#   x: 0.5268782
#   y: 0.5917955
#   z: 0.0093628
# }
# landmark {
#   x: 0.51508987
#   y: 0.59333247
#   z: 0.010921763
# }
# landmark {
#   x: 0.50532675
#   y: 0.6001056
#   z: 0.014707688
# }
# landmark {
#   x: 0.49452758
#   y: 0.6271755
#   z: 0.023098677
# }
# landmark {
#   x: 0.45766002
#   y: 0.6671616
#   z: 0.050641518
# }
# landmark {
#   x: 0.5002772
#   y: 0.64488244
#   z: 0.012860049
# }
# landmark {
#   x: 0.51024693
#   y: 0.6485952
#   z: 0.008364687
# }
# landmark {
#   x: 0.52315956
#   y: 0.6502068
#   z: 0.0062175086
# }
# landmark {
#   x: 0.5357003
#   y: 0.648867
#   z: 0.006396864
# }
# landmark {
#   x: 0.54577625
#   y: 0.6450692
#   z: 0.009054317
# }
# landmark {
#   x: 0.552953
#   y: 0.6406881
#   z: 0.010062203
# }
# landmark {
#   x: 0.4516808
#   y: 0.6774261
#   z: 0.08396998
# }
# landmark {
#   x: 0.5506317
#   y: 0.6989111
#   z: -0.028144486
# }
# landmark {
#   x: 0.5654905
#   y: 0.6579092
#   z: -0.025782399
# }
# landmark {
#   x: 0.56665564
#   y: 0.6864721
#   z: -0.04532441
# }
# landmark {
#   x: 0.5706428
#   y: 0.695916
#   z: -0.042652972
# }
# landmark {
#   x: 0.56585395
#   y: 0.6902538
#   z: -0.041597083
# }
# landmark {
#   x: 0.55275595
#   y: 0.70469564
#   z: -0.02560167
# }
# landmark {
#   x: 0.572382
#   y: 0.6964289
#   z: -0.0450252
# }
# landmark {
#   x: 0.5720295
#   y: 0.7019693
#   z: -0.0357397
# }
# landmark {
#   x: 0.5534076
#   y: 0.63080424
#   z: 0.016826903
# }
# landmark {
#   x: 0.5590487
#   y: 0.63331693
#   z: 0.011717075
# }
# landmark {
#   x: 0.56295365
#   y: 0.6339571
#   z: 0.0056734956
# }
# landmark {
#   x: 0.51034373
#   y: 0.6239247
#   z: 0.016032586
# }
# landmark {
#   x: 0.5048152
#   y: 0.6149875
#   z: 0.016537037
# }
# landmark {
#   x: 0.5898119
#   y: 0.65433836
#   z: -0.02640245
# }
# landmark {
#   x: 0.64096457
#   y: 0.6552822
#   z: 0.037944924
# }
# landmark {
#   x: 0.58487403
#   y: 0.70271504
#   z: -0.033395473
# }
# landmark {
#   x: 0.66883075
#   y: 0.6244462
#   z: 0.10097725
# }
# landmark {
#   x: 0.6159084
#   y: 0.6586272
#   z: 0.022607235
# }
# landmark {
#   x: 0.62450016
#   y: 0.6621395
#   z: 0.024668366
# }
# landmark {
#   x: 0.6326387
#   y: 0.66351247
#   z: 0.028794477
# }
# landmark {
#   x: 0.6435863
#   y: 0.66120994
#   z: 0.038886502
# }
# landmark {
#   x: 0.60892266
#   y: 0.6526824
#   z: 0.022867067
# }
# landmark {
#   x: 0.62973535
#   y: 0.6256069
#   z: 0.026265
# }
# landmark {
#   x: 0.62082464
#   y: 0.6247498
#   z: 0.024887664
# }
# landmark {
#   x: 0.6381405
#   y: 0.62965155
#   z: 0.03047649
# }
# landmark {
#   x: 0.6433191
#   y: 0.63656175
#   z: 0.034509853
# }
# landmark {
#   x: 0.6494993
#   y: 0.67129266
#   z: 0.042708438
# }
# landmark {
#   x: 0.59732234
#   y: 0.83747685
#   z: -0.02349642
# }
# landmark {
#   x: 0.6435576
#   y: 0.6536115
#   z: 0.042178504
# }
# landmark {
#   x: 0.66890126
#   y: 0.68096185
#   z: 0.08935435
# }
# landmark {
#   x: 0.65847087
#   y: 0.66614294
#   z: 0.055768993
# }
# landmark {
#   x: 0.6191121
#   y: 0.7062472
#   z: 0.0013380754
# }
# landmark {
#   x: 0.5845684
#   y: 0.7396243
#   z: -0.035770275
# }
# landmark {
#   x: 0.58051986
#   y: 0.75546694
#   z: -0.034508348
# }
# landmark {
#   x: 0.59439045
#   y: 0.74959713
#   z: -0.029498167
# }
# landmark {
#   x: 0.5993667
#   y: 0.76058036
#   z: -0.022821648
# }
# landmark {
#   x: 0.587434
#   y: 0.7602609
#   z: -0.029550653
# }
# landmark {
#   x: 0.5921608
#   y: 0.76606965
#   z: -0.023109883
# }
# landmark {
#   x: 0.6056118
#   y: 0.7918855
#   z: -0.013619656
# }
# landmark {
#   x: 0.5881243
#   y: 0.6910336
#   z: -0.047089066
# }
# landmark {
#   x: 0.5906136
#   y: 0.6782271
#   z: -0.047069464
# }
# landmark {
#   x: 0.65874606
#   y: 0.6243578
#   z: 0.044511195
# }
# landmark {
#   x: 0.60424906
#   y: 0.6704446
#   z: 0.0054491125
# }
# landmark {
#   x: 0.60461766
#   y: 0.70084226
#   z: -0.02178142
# }
# landmark {
#   x: 0.605361
#   y: 0.695698
#   z: -0.017691324
# }
# landmark {
#   x: 0.6445128
#   y: 0.71591365
#   z: 0.018201515
# }
# landmark {
#   x: 0.59055316
#   y: 0.6645797
#   z: -0.038173188
# }
# landmark {
#   x: 0.6420492
#   y: 0.60035324
#   z: 0.027450982
# }
# landmark {
#   x: 0.6525841
#   y: 0.6097784
#   z: 0.03644775
# }
# landmark {
#   x: 0.66501266
#   y: 0.5943182
#   z: 0.0869721
# }
# landmark {
#   x: 0.6035055
#   y: 0.60120356
#   z: 0.011277734
# }
# landmark {
#   x: 0.61236006
#   y: 0.6272888
#   z: 0.025513913
# }
# landmark {
#   x: 0.6128505
#   y: 0.7804026
#   z: -0.0075559528
# }
# landmark {
#   x: 0.64498085
#   y: 0.80905926
#   z: 0.079082094
# }
# landmark {
#   x: 0.59665537
#   y: 0.7067196
#   z: -0.021337898
# }
# landmark {
#   x: 0.58883184
#   y: 0.7091138
#   z: -0.025138903
# }
# landmark {
#   x: 0.60259575
#   y: 0.77757055
#   z: -0.009891357
# }
# landmark {
#   x: 0.59783787
#   y: 0.7756505
#   z: -0.013042293
# }
# landmark {
#   x: 0.65780187
#   y: 0.6032176
#   z: 0.043902867
# }
# landmark {
#   x: 0.6029296
#   y: 0.7086258
#   z: -0.018458609
# }
# landmark {
#   x: 0.62631315
#   y: 0.59661967
#   z: 0.018796463
# }
# landmark {
#   x: 0.6290012
#   y: 0.58583856
#   z: 0.020063834
# }
# landmark {
#   x: 0.6372453
#   y: 0.5468729
#   z: 0.05206803
# }
# landmark {
#   x: 0.6616893
#   y: 0.598099
#   z: 0.06270341
# }
# landmark {
#   x: 0.6326964
#   y: 0.5648115
#   z: 0.036068927
# }
# landmark {
#   x: 0.6632945
#   y: 0.62210995
#   z: 0.05502462
# }
# landmark {
#   x: 0.66624653
#   y: 0.6237307
#   z: 0.076677896
# }
# landmark {
#   x: 0.5828868
#   y: 0.74809366
#   z: -0.036215756
# }
# landmark {
#   x: 0.59086514
#   y: 0.7554928
#   z: -0.030239144
# }
# landmark {
#   x: 0.59594274
#   y: 0.7632494
#   z: -0.023883881
# }
# landmark {
#   x: 0.59369916
#   y: 0.70921445
#   z: -0.020343095
# }
# landmark {
#   x: 0.6001711
#   y: 0.7767214
#   z: -0.011682899
# }
# landmark {
#   x: 0.597521
#   y: 0.7773567
#   z: -0.018981881
# }
# landmark {
#   x: 0.59663033
#   y: 0.77480006
#   z: -0.0135409925
# }
# landmark {
#   x: 0.5947719
#   y: 0.6972619
#   z: -0.032041404
# }
# landmark {
#   x: 0.5895986
#   y: 0.76585996
#   z: -0.022255322
# }
# landmark {
#   x: 0.5846329
#   y: 0.7620597
#   z: -0.027001876
# }
# landmark {
#   x: 0.57826006
#   y: 0.7591623
#   z: -0.03148332
# }
# landmark {
#   x: 0.5776137
#   y: 0.807302
#   z: -0.030838795
# }
# landmark {
#   x: 0.5791235
#   y: 0.7899276
#   z: -0.037216112
# }
# landmark {
#   x: 0.5794503
#   y: 0.7805825
#   z: -0.037264425
# }
# landmark {
#   x: 0.5792088
#   y: 0.77251583
#   z: -0.034271773
# }
# landmark {
#   x: 0.57845145
#   y: 0.76776594
#   z: -0.032053694
# }
# landmark {
#   x: 0.5904597
#   y: 0.7719081
#   z: -0.022411095
# }
# landmark {
#   x: 0.591971
#   y: 0.77389103
#   z: -0.02459325
# }
# landmark {
#   x: 0.594024
#   y: 0.77823716
#   z: -0.026819386
# }
# landmark {
#   x: 0.5956543
#   y: 0.78406775
#   z: -0.025615724
# }
# landmark {
#   x: 0.6078241
#   y: 0.74907005
#   z: -0.015890207
# }
# landmark {
#   x: 0.6588811
#   y: 0.74793285
#   z: 0.11104824
# }
# landmark {
#   x: 0.5932021
#   y: 0.7741078
#   z: -0.017117208
# }
# landmark {
#   x: 0.5952777
#   y: 0.77495825
#   z: -0.018697534
# }
# landmark {
#   x: 0.5859658
#   y: 0.7142839
#   z: -0.027450154
# }
# landmark {
#   x: 0.59820735
#   y: 0.7173444
#   z: -0.014986967
# }
# landmark {
#   x: 0.5872569
#   y: 0.7117881
#   z: -0.026305228
# }
# landmark {
#   x: 0.6128434
#   y: 0.6813789
#   z: 0.008151396
# }
# landmark {
#   x: 0.6264627
#   y: 0.69379956
#   z: 0.011496691
# }
# landmark {
#   x: 0.60512936
#   y: 0.70340675
#   z: -0.013999774
# }
# landmark {
#   x: 0.6553872
#   y: 0.56812894
#   z: 0.06910042
# }
# landmark {
#   x: 0.6514144
#   y: 0.5779808
#   z: 0.049245976
# }
# landmark {
#   x: 0.6460219
#   y: 0.5908824
#   z: 0.03234798
# }
# landmark {
#   x: 0.59878284
#   y: 0.79851097
#   z: -0.02036014
# }
# landmark {
#   x: 0.60830516
#   y: 0.58358026
#   z: 0.0119749075
# }
# landmark {
#   x: 0.6118895
#   y: 0.55812794
#   z: 0.026179684
# }
# landmark {
#   x: 0.61551636
#   y: 0.5339557
#   z: 0.039615445
# }
# landmark {
#   x: 0.63956666
#   y: 0.66386837
#   z: 0.03412884
# }
# landmark {
#   x: 0.65745646
#   y: 0.6834163
#   z: 0.047235053
# }
# landmark {
#   x: 0.60458857
#   y: 0.6472368
#   z: 0.024166528
# }
# landmark {
#   x: 0.6521839
#   y: 0.6443087
#   z: 0.044488985
# }
# landmark {
#   x: 0.5990885
#   y: 0.6590968
#   z: 0.0030159594
# }
# landmark {
#   x: 0.60134095
#   y: 0.691612
#   z: -0.029982211
# }
# landmark {
#   x: 0.66425693
#   y: 0.6971853
#   z: 0.056574296
# }
# landmark {
#   x: 0.6522434
#   y: 0.68885183
#   z: 0.03595162
# }
# landmark {
#   x: 0.6419062
#   y: 0.68846905
#   z: 0.024565784
# }
# landmark {
#   x: 0.62568045
#   y: 0.68161696
#   z: 0.018355623
# }
# landmark {
#   x: 0.6136482
#   y: 0.6729055
#   z: 0.015238156
# }
# landmark {
#   x: 0.60473025
#   y: 0.6634766
#   z: 0.012830615
# }
# landmark {
#   x: 0.590188
#   y: 0.63549304
#   z: -0.0035937156
# }
# landmark {
#   x: 0.6611816
#   y: 0.72333515
#   z: 0.0473996
# }
# landmark {
#   x: 0.6588494
#   y: 0.64475626
#   z: 0.051185686
# }
# landmark {
#   x: 0.5834923
#   y: 0.6989207
#   z: -0.044440325
# }
# landmark {
#   x: 0.6031118
#   y: 0.6803367
#   z: -0.0018910946
# }
# landmark {
#   x: 0.66666484
#   y: 0.6886491
#   z: 0.120749116
# }
# landmark {
#   x: 0.59869725
#   y: 0.6533658
#   z: 0.012243638
# }
# landmark {
#   x: 0.6046832
#   y: 0.70681614
#   z: -0.0054740137
# }
# landmark {
#   x: 0.64673966
#   y: 0.6545698
#   z: 0.04428102
# }
# landmark {
#   x: 0.6017687
#   y: 0.6854216
#   z: -0.025009438
# }
# landmark {
#   x: 0.6533294
#   y: 0.77843803
#   z: 0.098006904
# }
# landmark {
#   x: 0.6044315
#   y: 0.64301175
#   z: 0.02782273
# }
# landmark {
#   x: 0.59663606
#   y: 0.6733106
#   z: -0.032869313
# }
# landmark {
#   x: 0.6320406
#   y: 0.8235973
#   z: 0.02109137
# }
# landmark {
#   x: 0.6275824
#   y: 0.8443334
#   z: 0.033407737
# }
# landmark {
#   x: 0.66430354
#   y: 0.7365587
#   z: 0.079607315
# }
# landmark {
#   x: 0.64224625
#   y: 0.81086415
#   z: 0.038367804
# }
# landmark {
#   x: 0.6675211
#   y: 0.6510765
#   z: 0.086314194
# }
# landmark {
#   x: 0.597574
#   y: 0.8544546
#   z: -0.021394355
# }
# landmark {
#   x: 0.58109164
#   y: 0.7042006
#   z: -0.034765624
# }
# landmark {
#   x: 0.6094308
#   y: 0.69310445
#   z: 0.00014826667
# }
# landmark {
#   x: 0.6642127
#   y: 0.6725948
#   z: 0.06595262
# }
# landmark {
#   x: 0.632831
#   y: 0.6560312
#   z: 0.030431405
# }
# landmark {
#   x: 0.6252543
#   y: 0.65504235
#   z: 0.02691384
# }
# landmark {
#   x: 0.5997184
#   y: 0.7810828
#   z: -0.017570062
# }
# landmark {
#   x: 0.6564777
#   y: 0.74996006
#   z: 0.042432997
# }
# landmark {
#   x: 0.57851905
#   y: 0.8731814
#   z: -0.025708256
# }
# landmark {
#   x: 0.60509396
#   y: 0.86304426
#   z: 0.00041131134
# }
# landmark {
#   x: 0.61569583
#   y: 0.85563076
#   z: 0.014966496
# }
# landmark {
#   x: 0.6179762
#   y: 0.6523576
#   z: 0.025541563
# }
# landmark {
#   x: 0.61136824
#   y: 0.648282
#   z: 0.026124304
# }
# landmark {
#   x: 0.60695267
#   y: 0.64533126
#   z: 0.02792376
# }
# landmark {
#   x: 0.66375625
#   y: 0.6460517
#   z: 0.062068917
# }
# landmark {
#   x: 0.6117735
#   y: 0.64008474
#   z: 0.026529303
# }
# landmark {
#   x: 0.61902326
#   y: 0.6408627
#   z: 0.026418505
# }
# landmark {
#   x: 0.62589777
#   y: 0.6420646
#   z: 0.028122745
# }
# landmark {
#   x: 0.63299793
#   y: 0.64501125
#   z: 0.031313792
# }
# landmark {
#   x: 0.6379309
#   y: 0.6485446
#   z: 0.034581058
# }
# landmark {
#   x: 0.6692677
#   y: 0.6540262
#   z: 0.11395995
# }
# landmark {
#   x: 0.63770264
#   y: 0.65583634
#   z: 0.03447035
# }
# landmark {
#   x: 0.6012862
#   y: 0.7370955
#   z: -0.019608587
# }
# landmark {
#   x: 0.5978244
#   y: 0.703482
#   z: -0.023420494
# }
# landmark {
#   x: 0.5866713
#   y: 0.7249397
#   z: -0.029327778
# }
# landmark {
#   x: 0.6206921
#   y: 0.83647174
#   z: 0.006074434
# }
# landmark {
#   x: 0.60961133
#   y: 0.84560055
#   z: -0.0075077983
# }
# landmark {
#   x: 0.5816146
#   y: 0.85950065
#   z: -0.03409125
# }
# landmark {
#   x: 0.6363053
#   y: 0.8309006
#   z: 0.05649697
# }
# landmark {
#   x: 0.6067473
#   y: 0.641138
#   z: 0.027528422
# }
# landmark {
#   x: 0.59490204
#   y: 0.6556335
#   z: -0.010751916
# }
# landmark {
#   x: 0.59336406
#   y: 0.86906
#   z: -0.014283719
# }
# landmark {
#   x: 0.6585965
#   y: 0.7651883
#   z: 0.069990754
# }
# landmark {
#   x: 0.5854458
#   y: 0.7693998
#   z: -0.02735025
# }
# landmark {
#   x: 0.5868382
#   y: 0.7730199
#   z: -0.029579943
# }
# landmark {
#   x: 0.5880172
#   y: 0.7794217
#   z: -0.031974755
# }
# landmark {
#   x: 0.5886911
#   y: 0.7880318
#   z: -0.03153291
# }
# landmark {
#   x: 0.589555
#   y: 0.8040172
#   z: -0.026543383
# }
# landmark {
#   x: 0.59553504
#   y: 0.7714444
#   z: -0.017251087
# }
# landmark {
#   x: 0.59902114
#   y: 0.7708775
#   z: -0.016649563
# }
# landmark {
#   x: 0.60220575
#   y: 0.7696
#   z: -0.015837237
# }
# landmark {
#   x: 0.6121133
#   y: 0.76387435
#   z: -0.010820071
# }
# landmark {
#   x: 0.6467906
#   y: 0.7488278
#   z: 0.020974383
# }
# landmark {
#   x: 0.5944591
#   y: 0.6463166
#   z: 0.00028290116
# }
# landmark {
#   x: 0.599331
#   y: 0.6284633
#   z: 0.021455975
# }
# landmark {
#   x: 0.6037104
#   y: 0.6339391
#   z: 0.026217734
# }
# landmark {
#   x: 0.5932063
#   y: 0.76967573
#   z: -0.016962377
# }
# landmark {
#   x: 0.64255756
#   y: 0.7850329
#   z: 0.025841774
# }
# landmark {
#   x: 0.59308237
#   y: 0.6224749
#   z: 0.0092065
# }
# landmark {
#   x: 0.5937843
#   y: 0.82068926
#   z: -0.024318712
# }
# landmark {
#   x: 0.5901223
#   y: 0.6454315
#   z: -0.015695719
# }
# landmark {
#   x: 0.5992999
#   y: 0.6769387
#   z: -0.014676822
# }
# landmark {
#   x: 0.579911
#   y: 0.82406217
#   z: -0.0331099
# }
# landmark {
#   x: 0.61397743
#   y: 0.8017525
#   z: -0.008495521
# }
# landmark {
#   x: 0.61048853
#   y: 0.72047144
#   z: -0.004239715
# }
# landmark {
#   x: 0.6046854
#   y: 0.8135639
#   z: -0.016526759
# }
# landmark {
#   x: 0.6312161
#   y: 0.7262129
#   z: 0.0032516485
# }
# landmark {
#   x: 0.6176624
#   y: 0.7366142
#   z: -0.004707874
# }
# landmark {
#   x: 0.63525116
#   y: 0.752096
#   z: 0.006035666
# }
# landmark {
#   x: 0.5820802
#   y: 0.8426729
#   z: -0.03543809
# }
# landmark {
#   x: 0.6027634
#   y: 0.68785965
#   z: -0.009623112
# }
# landmark {
#   x: 0.6202687
#   y: 0.81686294
#   z: -0.0012162827
# }
# landmark {
#   x: 0.60890627
#   y: 0.82821375
#   z: -0.012196559
# }
# landmark {
#   x: 0.62193936
#   y: 0.78612983
#   z: -0.0021469994
# }
# landmark {
#   x: 0.6512152
#   y: 0.77315766
#   z: 0.039006814
# }
# landmark {
#   x: 0.6318661
#   y: 0.79419816
#   z: 0.008345794
# }
# landmark {
#   x: 0.6517924
#   y: 0.79070324
#   z: 0.058001347
# }
# landmark {
#   x: 0.62207264
#   y: 0.7578907
#   z: -0.0034866922
# }
# landmark {
#   x: 0.5987991
#   y: 0.6678267
#   z: -0.005914031
# }
# landmark {
#   x: 0.59805405
#   y: 0.69568545
#   z: -0.032823455
# }
# landmark {
#   x: 0.60164404
#   y: 0.7037423
#   z: -0.024349323
# }
# landmark {
#   x: 0.5965415
#   y: 0.683865
#   z: -0.038441084
# }
# landmark {
#   x: 0.60792184
#   y: 0.61792266
#   z: 0.022180632
# }
# landmark {
#   x: 0.62281644
#   y: 0.61339664
#   z: 0.024087226
# }
# landmark {
#   x: 0.6349201
#   y: 0.6149108
#   z: 0.026814686
# }
# landmark {
#   x: 0.64452636
#   y: 0.62062263
#   z: 0.032027256
# }
# landmark {
#   x: 0.65047246
#   y: 0.63029677
#   z: 0.038314965
# }
# landmark {
#   x: 0.65188766
#   y: 0.6596093
#   z: 0.048415594
# }
# landmark {
#   x: 0.66797376
#   y: 0.7087867
#   z: 0.085291676
# }
# landmark {
#   x: 0.6452748
#   y: 0.6745492
#   z: 0.0361588
# }
# landmark {
#   x: 0.6367412
#   y: 0.67444897
#   z: 0.028622186
# }
# landmark {
#   x: 0.6254271
#   y: 0.67134917
#   z: 0.022936895
# }
# landmark {
#   x: 0.6145246
#   y: 0.665365
#   z: 0.019672778
# }
# landmark {
#   x: 0.60613674
#   y: 0.6580062
#   z: 0.019114666
# }
# landmark {
#   x: 0.6007147
#   y: 0.651033
#   z: 0.018239705
# }
# landmark {
#   x: 0.6625557
#   y: 0.71882474
#   z: 0.1194549
# }
# landmark {
#   x: 0.59987944
#   y: 0.7086646
#   z: -0.020777
# }
# landmark {
#   x: 0.59515923
#   y: 0.66398835
#   z: -0.020645188
# }
# landmark {
#   x: 0.5932439
#   y: 0.6919376
#   z: -0.04124679
# }
# landmark {
#   x: 0.586536
#   y: 0.6991425
#   z: -0.040228494
# }
# landmark {
#   x: 0.59187394
#   y: 0.6955943
#   z: -0.03737126
# }
# landmark {
#   x: 0.59634393
#   y: 0.7131153
#   z: -0.019427393
# }
# landmark {
#   x: 0.585695
#   y: 0.6991404
#   z: -0.04301332
# }
# landmark {
#   x: 0.58326054
#   y: 0.7041623
#   z: -0.034054037
# }
# landmark {
#   x: 0.6015562
#   y: 0.6414795
#   z: 0.025406707
# }
# landmark {
#   x: 0.5967878
#   y: 0.6416957
#   z: 0.018261569
# }
# landmark {
#   x: 0.59470505
#   y: 0.6408757
#   z: 0.010995209
# }
# landmark {
#   x: 0.6410812
#   y: 0.6511978
#   z: 0.037867848
# }
# landmark {
#   x: 0.647173
#   y: 0.64458436
#   z: 0.03974826
# }

# %%
import csv
import os
import numpy as np

# %%
num_coords=len(results.pose_landmarks.landmark)+len(results.face_landmarks.landmark)
num_coords
# Out:
# 501

# %%
# landmarks=['class']
# for val in range(1,num_coords+1):
#     landmarks +=['x{}'.format(val),'y{}'.format(val),'z{}'.format(val,'v{}'.format(val))]

# %%
# landmarks

# %%
# landmarks[-4]

# %%
# with open('coords.csv',mode='a',newline='')as f:
#     csv_writer=csv.writer(f,delimiter=',',quotechar='"',quoting=csv.QUOTE_MINIMAL)
#     csv_writer.writerow(landmarks)

# %%
# class_name="outofwindow"

# %%
# cap = cv2.VideoCapture(0)
# # Initiate holistic model
# with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
#     while cap.isOpened():
#         ret, frame = cap.read()
        
#         # Recolor Feed
#         image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#         image.flags.writeable = False        
        
#         # Make Detections
#         results = holistic.process(image)
#         # print(results.face_landmarks)
        
#         # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
#         # Recolor image back to BGR for rendering
#         image.flags.writeable = True   
#         image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
#         # 1. Draw face landmarks
#         mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
#                                  mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
#                                  mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
#                                  )
        
#         # 2. Right hand
#         mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
#                                  mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
#                                  mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
#                                  )

#         # 3. Left Hand
#         mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
#                                  mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
#                                  mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
#                                  )

#         # 4. Pose Detections
#         mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
#                                  mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
#                                  mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
#                                  )
#         # Export coordinates
#         try:
#             # Extract Pose landmarks
#             pose = results.pose_landmarks.landmark
#             pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
#             # Extract Face landmarks
#             face = results.face_landmarks.landmark
#             face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
#             # Concate rows
#             row = pose_row+face_row
            
#             # Append class name 
#             row.insert(0, class_name)
            
#             # Export to CSV
#             with open('coords.csv', mode='a', newline='') as f:
#                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                 csv_writer.writerow(row) 
            
#         except:
#             pass
                        
#         cv2.imshow('Raw Webcam Feed', image)

#         if cv2.waitKey(10) & 0xFF == ord('q'):
#             break

# cap.release()
# cv2.destroyAllWindows()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('coords.csv',sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
# Out:
# C:\Users\Deepa Nikade\AppData\Local\Temp\ipykernel_19956\2751913128.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df=pd.read_csv('coords.csv',sep=',', error_bad_lines=False, index_col=False, dtype='unicode')

# %%
df
# Out:
#             class           x1           y1            z1           x2  \
# 0             sad  0.550060689   0.41492033  -1.540184617  0.999711335
# 1             sad  0.549745739  0.415983379  -1.435512304  0.999690294
# 2             sad  0.549604714  0.417136759  -1.447685957  0.999688864
# 3             sad  0.549495459  0.417805284  -1.449486494  0.999685407
# 4             sad  0.549473345  0.417993486  -1.372476578  0.999683738
# ...           ...          ...          ...           ...          ...
# 1652  outofwindow   0.63456434  0.667351484  -2.728379726  0.977074206
# 1653  outofwindow  0.688241601  0.718895793  -3.123790979  0.978686273
# 1654  outofwindow  0.715386868  0.588263571   -1.83538723  0.979942501
# 1655  outofwindow  0.714061618  0.529766321  -1.628304243  0.980618775
# 1656  outofwindow  0.787756622  0.488625884  -1.286193728  0.982300282
#
#                y2           z2            x3           y3           z3  ...  \
# 0     0.578980088   0.34542644  -1.474510431  0.999437988  0.597540557  ...
# 1     0.578452468   0.34610045  -1.371326447  0.999400914  0.596917629  ...
# 2     0.578128874  0.346756071  -1.382127523   0.99940151  0.596477985  ...
# 3     0.577892601  0.347141773  -1.383707285  0.999397933  0.596165836  ...
# 4     0.577700496  0.347226709  -1.310265779  0.999390781  0.595867991  ...
# ...           ...          ...           ...          ...          ...  ...
# 1652  0.701460421  0.542982221  -2.705180645  0.973851681  0.739975929  ...
# 1653   0.74986726  0.595112443  -3.126339436  0.975807726  0.787321925  ...
# 1654  0.763766885  0.490251273  -1.710613847  0.976344943  0.795408845  ...
# 1655  0.757705986  0.440329403  -1.502306819  0.976959944  0.787513137  ...
# 1656  0.820038617  0.403463185  -1.170133591  0.978868723   0.84441185  ...
#
#               z665 x666         y666         z666          x667 y667  \
# 0     -0.000923904    0  0.618939638  0.350442439   0.023692606    0
# 1     -0.000859436    0  0.619377494  0.350291491   0.023892278    0
# 2     -0.000741538    0  0.619570494   0.35116148   0.024126302    0
# 3     -0.000680414    0  0.619656384   0.35126403   0.024309518    0
# 4     -0.000252653    0  0.619623482  0.349586606   0.025064524    0
# ...            ...  ...          ...          ...           ...  ...
# 1652  -0.053111002    0  0.816568196  0.589651525  -0.028165659    0
# 1653  -0.044968098    0  0.846428692  0.609926701  -0.015838645    0
# 1654  -0.019834219    0  0.843132496  0.460084885   0.010251732    0
# 1655  -0.010980104    0  0.821096897  0.405285507   0.015163722    0
# 1656   0.014276871    0  0.874276757  0.368881792   0.058895376    0
#
#              z667         x668          y668 z668
# 0     0.625114858  0.343877614   0.024583548    0
# 1     0.625436664   0.34513095   0.024666978    0
# 2     0.625724077  0.345778942   0.024908001    0
# 3      0.62581414  0.345856518   0.025105003    0
# 4     0.625690043  0.344075382   0.025952697    0
# ...           ...          ...           ...  ...
# 1652  0.827606201  0.573329091  -0.028405078    0
# 1653  0.856593251    0.5962919  -0.015704017    0
# 1654  0.852023005  0.451116741   0.011114531    0
# 1655  0.829935551  0.395278752   0.016276186    0
# 1656  0.880510986  0.362475306   0.061728977    0
#
# [1657 rows x 2005 columns]

# %%
# df.head()

# %%
# df.tail()

# %%
# df[df['class']=='sad']

# %%
# df[df['class']=='Happy']

# %%
X = df.drop('class', axis=1) 
y = df['class']

# %%
y
# Out:
# 0               sad
# 1               sad
# 2               sad
# 3               sad
# 4               sad
#            ...
# 1652    outofwindow
# 1653    outofwindow
# 1654    outofwindow
# 1655    outofwindow
# 1656    outofwindow
# Name: class, Length: 1657, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
# df

# %%
X_train
# Out:
#             x1        y1        z1        x2        y2        z2        x3  \
# 1287  0.739617  0.394585 -0.569364  0.999018  0.718377  0.333924 -0.503814
# 1060  0.348796  0.447317 -0.938041  0.999210  0.380553  0.376611 -0.941358
# 99    0.622495  0.520153 -1.579430  0.999448  0.634511  0.447049 -1.523404
# 1312  0.738727  0.403332 -0.538118  0.999411  0.719090  0.341913 -0.473113
# 688   0.537546  0.379331 -1.135556  0.999653  0.562758  0.314575 -1.063195
# ...        ...       ...       ...       ...       ...       ...       ...
# 1228  0.798289  0.433317 -0.763228  0.996139  0.781287  0.368950 -0.687965
# 1077  0.339798  0.456295 -0.872698  0.999339  0.375622  0.383983 -0.876816
# 1318  0.739036  0.403585 -0.596312  0.999465  0.719375  0.343112 -0.528816
# 723   0.534678  0.382611 -1.161258  0.999624  0.561004  0.318126 -1.086957
# 815   0.336833  0.480576 -0.710167  0.999392  0.372377  0.405231 -0.737513
#
#             y3        z3        x4  ...      z665  x666      y666      z666  \
# 1287  0.998550  0.718279  0.334447  ...  0.004247   0.0  0.721780  0.299208
# 1060  0.997850  0.400148  0.373581  ... -0.006422   0.0  0.404544  0.373137
# 99    0.998900  0.647655  0.444923  ... -0.009895   0.0  0.679347  0.448529
# 1312  0.999152  0.719506  0.342186  ... -0.001556   0.0  0.717196  0.301564
# 688   0.999177  0.576865  0.316033  ... -0.000600   0.0  0.597348  0.319121
# ...        ...       ...       ...  ...       ...   ...       ...       ...
# 1228  0.993711  0.780139  0.368696  ...  0.001722   0.0  0.778352  0.309005
# 1077  0.998214  0.393690  0.381443  ... -0.007513   0.0  0.396912  0.378630
# 1318  0.999209  0.719813  0.343493  ...  0.009088   0.0  0.737070  0.323716
# 723   0.999139  0.575705  0.319833  ... -0.004347   0.0  0.600675  0.335086
# 815   0.998431  0.389132  0.401424  ... -0.013019   0.0  0.385037  0.402928
#
#           x667  y667      z667      x668      y668  z668
# 1287  0.037365   0.0  0.722269  0.295300  0.039313   0.0
# 1060 -0.027312   0.0  0.411791  0.361785 -0.029796   0.0
# 99    0.028413   0.0  0.684284  0.439579  0.030707   0.0
# 1312  0.022344   0.0  0.719138  0.295516  0.023844   0.0
# 688   0.020066   0.0  0.603199  0.313433  0.020993   0.0
# ...        ...   ...       ...       ...       ...   ...
# 1228  0.032810   0.0  0.778588  0.304406  0.034773   0.0
# 1077 -0.029552   0.0  0.404210  0.367570 -0.032149   0.0
# 1318  0.047146   0.0  0.736982  0.318400  0.050102   0.0
# 723   0.015478   0.0  0.606393  0.329515  0.016155   0.0
# 815  -0.047004   0.0  0.392265  0.392713 -0.050678   0.0
#
# [1159 rows x 2004 columns]

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression(max_iter=2100)),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier(max_iter=2100)),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
pipelines
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression(max_iter=2100))]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier(max_iter=2100))]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
type(X_train['x1'][1128])
# Out:
# str

# %%
from tqdm.notebook import tqdm

# %%
fit_models = {}
X_train=X_train.astype(float)
for algo, pipeline in tqdm(pipelines.items()):
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression(max_iter=2100))]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier(max_iter=2100))]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['sad', 'moving left', 'Happy', 'moving left', 'sad', 'sad',
#        'moving right', 'sad', 'Happy', 'sad', 'moving left',
#        'moving right', 'Confused', 'sad', 'sad', 'Confused', 'Happy',
#        'Confused', 'sad', 'moving left', 'Happy', 'sad', 'Confused',
#        'Confused', 'sad', 'Happy', 'moving right', 'outofwindow', 'Happy',
#        'moving right', 'moving right', 'Confused', 'moving right',
#        'Confused', 'sad', 'moving right', 'moving right', 'sad',
#        'moving right', 'Happy', 'Confused', 'moving left', 'sad',
#        'Confused', 'sad', 'sad', 'Confused', 'sad', 'moving right',
#        'Happy', 'moving left', 'sad', 'moving right', 'sad', 'sad',
#        'moving left', 'Confused', 'Happy', 'Confused', 'moving right',
#        'Confused', 'Happy', 'sad', 'moving right', 'moving left', 'sad',
#        'Happy', 'Happy', 'Confused', 'Happy', 'moving left', 'Confused',
#        'Confused', 'sad', 'Happy', 'moving left', 'Happy', 'outofwindow',
#        'Confused', 'moving left', 'sad', 'Confused', 'sad',
#        'moving right', 'Happy', 'sad', 'moving right', 'moving left',
#        'moving right', 'Happy', 'moving right', 'moving right',
#        'moving right', 'moving left', 'Confused', 'moving left',
#        'moving right', 'moving right', 'moving left', 'sad', 'Happy',
#        'Confused', 'sad', 'moving right', 'moving right', 'Confused',
#        'sad', 'moving left', 'Confused', 'sad', 'sad', 'moving left',
#        'sad', 'sad', 'Happy', 'sad', 'moving left', 'Confused', 'Happy',
#        'moving right', 'moving right', 'Happy', 'moving right',
#        'Confused', 'moving right', 'Confused', 'Happy', 'sad',
#        'moving right', 'sad', 'Confused', 'sad', 'moving left', 'Happy',
#        'moving right', 'sad', 'moving right', 'Happy', 'Confused',
#        'moving left', 'sad', 'moving right', 'Happy', 'moving right',
#        'Confused', 'moving right', 'moving right', 'moving right',
#        'moving left', 'moving right', 'sad', 'moving right',
#        'moving right', 'moving right', 'sad', 'moving right',
#        'moving right', 'Confused', 'Confused', 'moving left', 'sad',
#        'sad', 'Confused', 'moving left', 'sad', 'Confused', 'sad', 'sad',
#        'Happy', 'moving left', 'moving right', 'Confused', 'sad',
#        'moving right', 'Confused', 'Confused', 'sad', 'sad', 'Confused',
#        'Confused', 'Confused', 'outofwindow', 'moving left', 'sad',
#        'moving right', 'sad', 'Confused', 'Happy', 'moving right',
#        'moving right', 'Confused', 'Confused', 'Happy', 'Confused',
#        'Confused', 'sad', 'sad', 'Happy', 'Happy', 'sad', 'moving right',
#        'Happy', 'Confused', 'moving left', 'sad', 'Happy', 'moving right',
#        'sad', 'Confused', 'moving right', 'sad', 'Happy', 'moving left',
#        'moving left', 'sad', 'moving left', 'Happy', 'Confused',
#        'moving left', 'moving right', 'Confused', 'sad', 'Confused',
#        'Happy', 'sad', 'Happy', 'moving right', 'sad', 'moving right',
#        'sad', 'moving right', 'Confused', 'moving right', 'sad', 'sad',
#        'moving right', 'Happy', 'sad', 'Happy', 'moving right',
#        'moving right', 'Confused', 'moving right', 'moving right',
#        'moving right', 'moving right', 'sad', 'moving right', 'Confused',
#        'moving left', 'moving right', 'moving right', 'Happy',
#        'moving left', 'Happy', 'moving right', 'sad', 'Confused',
#        'Confused', 'sad', 'sad', 'Happy', 'Confused', 'Confused',
#        'moving right', 'Happy', 'Happy', 'Confused', 'Confused',
#        'moving left', 'moving left', 'sad', 'Confused', 'moving left',
#        'Confused', 'sad', 'sad', 'Happy', 'moving right', 'Confused',
#        'sad', 'sad', 'Happy', 'sad', 'sad', 'sad', 'moving left', 'Happy',
#        'moving right', 'moving right', 'Happy', 'sad', 'Happy',
#        'moving right', 'sad', 'sad', 'moving right', 'sad',
#        'moving right', 'sad', 'moving right', 'moving right',
#        'moving right', 'sad', 'sad', 'Confused', 'sad', 'Confused',
#        'Happy', 'sad', 'moving right', 'sad', 'sad', 'moving right',
#        'sad', 'moving right', 'moving right', 'moving right', 'Confused',
#        'moving right', 'moving left', 'moving right', 'sad', 'Happy',
#        'Happy', 'moving right', 'Happy', 'Confused', 'moving left', 'sad',
#        'Happy', 'Confused', 'sad', 'Confused', 'sad', 'sad', 'Confused',
#        'sad', 'Happy', 'moving right', 'sad', 'sad', 'Happy', 'sad',
#        'moving right', 'moving right', 'Confused', 'Confused',
#        'moving right', 'moving right', 'sad', 'moving right',
#        'moving left', 'moving right', 'Happy', 'Confused', 'sad', 'Happy',
#        'sad', 'Happy', 'moving right', 'Happy', 'sad', 'sad', 'Confused',
#        'sad', 'moving left', 'moving right', 'moving right',
#        'moving right', 'Happy', 'sad', 'moving right', 'moving right',
#        'moving right', 'Happy', 'Happy', 'moving right', 'Happy', 'sad',
#        'Happy', 'Confused', 'Happy', 'Confused', 'Happy', 'sad', 'Happy',
#        'moving right', 'sad', 'Confused', 'moving left', 'Happy', 'sad',
#        'Happy', 'sad', 'sad', 'sad', 'moving right', 'Happy', 'Confused',
#        'sad', 'Happy', 'sad', 'Confused', 'Happy', 'Happy',
#        'moving right', 'moving right', 'sad', 'moving right', 'sad',
#        'moving right', 'sad', 'sad', 'sad', 'moving right',
#        'moving right', 'Happy', 'sad', 'Happy', 'Happy', 'moving left',
#        'sad', 'Confused', 'sad', 'moving right', 'Happy', 'moving right',
#        'moving right', 'sad', 'moving right', 'sad', 'Confused',
#        'moving left', 'moving right', 'Confused', 'sad', 'outofwindow',
#        'Happy', 'moving right', 'moving right', 'moving left', 'Happy',
#        'Happy', 'moving right', 'Happy', 'Happy', 'sad', 'Happy', 'sad',
#        'moving right', 'sad', 'moving left', 'moving right', 'Happy',
#        'Confused', 'sad', 'sad', 'Confused', 'Confused', 'sad', 'sad',
#        'sad', 'Happy', 'Happy', 'Confused', 'sad', 'sad', 'sad',
#        'Confused', 'sad', 'moving left', 'Confused', 'sad', 'sad',
#        'moving left', 'Confused', 'sad', 'moving right', 'moving right',
#        'sad', 'sad', 'sad', 'moving left', 'moving right', 'Happy',
#        'Confused', 'sad', 'sad', 'sad', 'Confused', 'sad', 'moving right',
#        'Confused', 'outofwindow', 'Happy', 'sad', 'Confused'],
#       dtype='<U12')

# %%
from sklearn.metrics import accuracy_score 
import pickle

# %%
for algo, model in model.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 0.9959839357429718
# rc 0.9939759036144579
# rf 0.9959839357429718
# gb 0.9959839357429718

# %%
# fit_models['rf'].predict(X_test)
# Out:
# array(['sad', 'moving left', 'Happy', 'moving left', 'sad', 'sad',
#        'moving right', 'sad', 'Happy', 'sad', 'moving left',
#        'moving right', 'Confused', 'sad', 'sad', 'Confused', 'Happy',
#        'Confused', 'sad', 'moving left', 'Happy', 'sad', 'Confused',
#        'Confused', 'sad', 'Happy', 'moving right', 'outofwindow', 'Happy',
#        'moving right', 'moving right', 'Confused', 'moving right',
#        'Confused', 'sad', 'moving right', 'moving right', 'sad',
#        'moving right', 'Happy', 'Confused', 'moving left', 'sad',
#        'Confused', 'sad', 'sad', 'Confused', 'sad', 'moving right',
#        'Happy', 'moving left', 'sad', 'moving right', 'sad', 'sad',
#        'moving left', 'Confused', 'Happy', 'Confused', 'moving right',
#        'Confused', 'Happy', 'sad', 'moving right', 'moving left', 'sad',
#        'Happy', 'Happy', 'Confused', 'Happy', 'moving left', 'Confused',
#        'Confused', 'sad', 'Happy', 'moving left', 'Happy', 'Happy',
#        'Confused', 'moving left', 'sad', 'Confused', 'sad',
#        'moving right', 'Happy', 'sad', 'moving right', 'moving left',
#        'moving right', 'outofwindow', 'moving right', 'moving right',
#        'moving right', 'moving left', 'Confused', 'moving left',
#        'moving right', 'moving right', 'moving left', 'sad', 'Happy',
#        'Confused', 'sad', 'moving right', 'moving right', 'Confused',
#        'sad', 'moving left', 'Confused', 'sad', 'sad', 'moving left',
#        'sad', 'sad', 'Happy', 'sad', 'moving left', 'Confused', 'Happy',
#        'moving right', 'moving right', 'Happy', 'moving right',
#        'Confused', 'moving right', 'Confused', 'Happy', 'sad',
#        'moving right', 'sad', 'Confused', 'sad', 'moving left', 'Happy',
#        'moving right', 'sad', 'moving right', 'Happy', 'Confused',
#        'moving left', 'sad', 'moving right', 'Happy', 'moving right',
#        'Confused', 'moving right', 'moving right', 'moving right',
#        'moving left', 'moving right', 'sad', 'moving right',
#        'moving right', 'moving right', 'sad', 'moving right',
#        'moving right', 'Confused', 'Confused', 'moving left', 'sad',
#        'sad', 'Confused', 'moving left', 'sad', 'Confused', 'sad', 'sad',
#        'Happy', 'moving left', 'moving right', 'Confused', 'sad',
#        'moving right', 'Confused', 'Confused', 'sad', 'sad', 'Confused',
#        'Confused', 'Confused', 'outofwindow', 'moving left', 'sad',
#        'moving right', 'sad', 'Confused', 'Happy', 'moving right',
#        'moving right', 'Confused', 'Confused', 'Happy', 'Confused',
#        'Confused', 'sad', 'sad', 'Happy', 'Happy', 'sad', 'moving right',
#        'Happy', 'Confused', 'moving left', 'sad', 'Happy', 'moving right',
#        'sad', 'Confused', 'moving right', 'sad', 'Happy', 'moving left',
#        'moving left', 'sad', 'moving left', 'Happy', 'Confused',
#        'moving left', 'moving right', 'Confused', 'sad', 'Confused',
#        'Happy', 'sad', 'Happy', 'moving right', 'sad', 'moving right',
#        'sad', 'moving right', 'Confused', 'moving right', 'sad', 'sad',
#        'moving right', 'Happy', 'sad', 'Happy', 'moving right',
#        'moving right', 'Confused', 'moving right', 'moving right',
#        'moving right', 'moving right', 'sad', 'moving right', 'Confused',
#        'moving left', 'moving right', 'moving right', 'Happy',
#        'moving left', 'Happy', 'moving right', 'sad', 'Confused',
#        'Confused', 'sad', 'sad', 'Happy', 'Confused', 'Confused',
#        'moving right', 'Happy', 'Happy', 'Confused', 'Confused',
#        'moving left', 'moving left', 'sad', 'Confused', 'moving left',
#        'Confused', 'sad', 'sad', 'Happy', 'moving right', 'Confused',
#        'sad', 'sad', 'Happy', 'sad', 'sad', 'sad', 'moving left', 'Happy',
#        'moving right', 'moving right', 'Happy', 'sad', 'Happy',
#        'moving right', 'sad', 'sad', 'moving right', 'sad',
#        'moving right', 'sad', 'moving right', 'moving right',
#        'moving right', 'sad', 'sad', 'Confused', 'sad', 'Confused',
#        'Happy', 'sad', 'moving right', 'sad', 'sad', 'moving right',
#        'sad', 'moving right', 'moving right', 'moving right', 'Confused',
#        'moving right', 'moving left', 'moving right', 'sad', 'Happy',
#        'Happy', 'moving right', 'Happy', 'Confused', 'moving left', 'sad',
#        'Happy', 'Confused', 'sad', 'Confused', 'sad', 'sad', 'Confused',
#        'sad', 'Happy', 'moving right', 'sad', 'sad', 'Happy', 'sad',
#        'moving right', 'moving right', 'Confused', 'Confused',
#        'moving right', 'moving right', 'sad', 'moving right',
#        'moving left', 'moving right', 'Happy', 'Confused', 'sad', 'Happy',
#        'sad', 'Happy', 'moving right', 'Happy', 'sad', 'sad', 'Confused',
#        'sad', 'moving left', 'moving right', 'moving right',
#        'moving right', 'Happy', 'sad', 'moving right', 'moving right',
#        'outofwindow', 'Happy', 'Happy', 'moving right', 'Happy', 'sad',
#        'Happy', 'Confused', 'Happy', 'Confused', 'Happy', 'sad', 'Happy',
#        'moving right', 'sad', 'Confused', 'moving left', 'Happy', 'sad',
#        'Happy', 'sad', 'sad', 'sad', 'moving right', 'Happy', 'Confused',
#        'sad', 'Happy', 'sad', 'Confused', 'Happy', 'Happy',
#        'moving right', 'moving right', 'sad', 'moving right', 'sad',
#        'moving right', 'sad', 'sad', 'sad', 'moving right',
#        'moving right', 'Happy', 'sad', 'Happy', 'outofwindow',
#        'moving left', 'sad', 'Confused', 'sad', 'moving right', 'Happy',
#        'moving right', 'moving right', 'sad', 'moving right', 'sad',
#        'Confused', 'moving left', 'moving right', 'Confused', 'sad',
#        'Confused', 'Happy', 'moving right', 'moving right', 'moving left',
#        'Happy', 'Happy', 'moving right', 'Happy', 'Happy', 'sad', 'Happy',
#        'sad', 'moving right', 'sad', 'moving left', 'moving right',
#        'Happy', 'Confused', 'sad', 'sad', 'Confused', 'Confused', 'sad',
#        'sad', 'sad', 'Happy', 'Happy', 'Confused', 'sad', 'sad', 'sad',
#        'Confused', 'sad', 'moving left', 'Confused', 'sad', 'sad',
#        'moving left', 'Confused', 'sad', 'moving right', 'moving right',
#        'sad', 'sad', 'sad', 'moving left', 'moving right', 'Happy',
#        'Confused', 'sad', 'sad', 'sad', 'Confused', 'sad', 'moving right',
#        'Confused', 'outofwindow', 'Happy', 'sad', 'Confused'],
#       dtype=object)

# %%
# y_test
# Out:
# 237             sad
# 1226    moving left
# 662           Happy
# 1279    moving left
# 139             sad
#            ...
# 1551       Confused
# 1632    outofwindow
# 537           Happy
# 71              sad
# 1366       Confused
# Name: class, Length: 498, dtype: object

# %%
with open('body_language.pkl', 'wb') as f:
    pickle.dump(fit_models, f)

# %%
with open('body_language.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression(max_iter=2100))]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier(max_iter=2100))]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
import win32api
import datetime
ans=[]
count=0
flag=True
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened() and flag:
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
            
            # Append class name 
#             row.insert(0, class_name)
            
#             # Export to CSV
#             with open('coords.csv', mode='a', newline='') as f:
#                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                 csv_writer.writerow(row)

            #make detection
            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class, body_language_prob)
            if len(ans)==0 or ans[-1][1]!=body_language_class:
                now = datetime.datetime.now()
                ans.append([now.strftime('%Y-%m-%d  %H:%M:%S'),body_language_class])
            
            if body_language_class=="outofwindow":
                if count<=4:
#                     font=cv2.FONT_HERSHEY_SIMPLEX
#                     cv2.putText(frame,"WARNING!: FACE NOT DETECTED",(50,50),font,1,(0,255,255),2,cv2.LINE_AA,True)
                    count+=1
                else:
                    flag=False
#                     cap.release()
#                     win32api.MessageBox("END OF METTING")
                        
                    break

                    
            
            # Grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            
            

            
        except Exception as e:
            print(e)
        
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# moving right [1.59317242e-06 1.83566003e-06 2.00557826e-04 9.93383738e-01
#  1.59495705e-07 6.41211554e-03]
# moving right [2.63742650e-06 3.03885402e-06 2.07313114e-04 9.96973420e-01
#  2.65283794e-07 2.81332529e-03]
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# moving right